# %% [markdown]
# ## Backtesting

# %% [markdown]
# ### imports

# %%
import yaml
import torch
import torch.nn as nn
import torch.optim as optim
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler
import ffn
import logging
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay


# Configure logging
logging.basicConfig(level=logging.DEBUG, format='%(asctime)s - %(levelname)s - %(message)s')
logging.getLogger('matplotlib').setLevel(logging.WARNING)

# Load configuration from YAML
def load_config(yaml_file_path):
    with open(yaml_file_path, 'r') as file:
        config = yaml.safe_load(file)
    return config

# %% [markdown]
# #### Signal

# %%
# Define Signal class to use dynamic thresholds from YAML configuration
class Signal:
    def __init__(self, current_price, buy_signal, sell_signal):
        self.current_price = current_price
        self.buy_signal = eval(buy_signal["function"])
        self.sell_signal = eval(sell_signal["function"])
        self.buy_threshold = buy_signal["params"]["buy_threshold"]
        self.sell_threshold = sell_signal["params"]["sell_threshold"]

    def generate_buy_signal(self, predicted_high):
        return self.buy_signal(self.current_price, predicted_high, self.buy_threshold)

    def generate_sell_signal(self, buy_price):
        return self.sell_signal(self.current_price, buy_price, self.sell_threshold) if buy_price else False

# %% [markdown]
# #### Strategy

# %%
class Strategy:
    def __init__(self, config):
        strategy_config = config["strategies"]["trading_strategy"]["params"]
        self.initial_cash = strategy_config["initial_cash"]
        self.position_size_factor = strategy_config["position_size_factor"]
        self.cash = self.initial_cash
        self.position = 0
        self.buy_price = None
        self.total_trades = 0
        self.winning_trades = 0
        self.losing_trades = 0
        self.portfolio_value = []
        self.current_price = None
        self.decisions = []
        self.X_test_df = None
        #self.max_holding_time = strategy_config["max_holding_time"]
        self.last_trade_timestamp = None
        self.previous_signal = None  # Track the previous signal
        self.signal_strength =0

    def make_decision(self, timestamp, prediction, action, current_price):
        """Log each decision with debugging information."""
        self.decisions.append({
            "timestamp": timestamp,
            "prediction": prediction,
            "action": action,
            "current_price": current_price,
            "actual_price": None,
        })




    def execute_trade(self, signal, future_timestamp, predicted_high, current_price):
        self.current_price = current_price

        # Determine the signal strength
        if self.previous_signal == signal:
            self.signal_strength += 1
        else:
            self.signal_strength = 1
        self.previous_signal = signal

        # Buy decision
        if self.position == 0 and signal.generate_buy_signal(predicted_high):
            amount_to_invest = self.position_size_factor * self.cash * self.signal_strength
            shares_to_buy = amount_to_invest // self.current_price
            self.cash -= shares_to_buy * self.current_price
            self.position += shares_to_buy
            self.buy_price = self.current_price
            self.make_decision(future_timestamp, predicted_high, "buy", self.current_price)  # Log buy event

        # Add to position if the signal is strong
        elif self.position > 0 and signal.generate_buy_signal(predicted_high):
            amount_to_invest = self.position_size_factor * self.cash * self.signal_strength
            shares_to_buy = amount_to_invest // self.current_price
            self.cash -= shares_to_buy * self.current_price
            self.position += shares_to_buy
            self.make_decision(future_timestamp, predicted_high, "buy", self.current_price)  # Log buy event

        # Sell decision
        elif self.position > 0 and signal.generate_sell_signal(self.buy_price):
            trade_value = self.position * self.current_price
            self.cash += trade_value
            profit_or_loss = trade_value - (self.position * self.buy_price)
            if profit_or_loss > 0:
                self.winning_trades += 1
            else:
                self.losing_trades += 1
            self.total_trades += 1
            self.position = 0
            self.buy_price = None
            self.make_decision(future_timestamp, predicted_high, "sell", self.current_price)  # Log sell event

        # Exit decision
        elif self.position > 0 and not signal.generate_buy_signal(predicted_high) and not signal.generate_sell_signal(self.buy_price):
            trade_value = self.position * self.current_price
            self.cash += trade_value
            self.total_trades += 1
            self.position = 0
            self.buy_price = None
            self.make_decision(future_timestamp, predicted_high, "exit", self.current_price)  # Log exit event

        # Update portfolio value for the minute
        self.portfolio_value.append(self.cash + self.position * self.current_price)




    def print_trade_statistics(self):
        """Print the total trades and winning trades."""
        print(f"Total Trades: {self.total_trades}, Winning Trades: {self.winning_trades}")

    def fetch_actual_price(self, timestamp):
        try:
            mask = self.X_test_df.index == timestamp
            actual_row = self.X_test_df.loc[mask].iloc[0] if not self.X_test_df.loc[mask].empty else None

            if actual_row is not None:
                return actual_row['high']
            else:
                return None
        except KeyError:
            return None

    def evaluate_decisions(self):
        y_true = []
        y_pred = []
        for decision in self.decisions:
            actual_price = self.fetch_actual_price(decision["timestamp"])
            decision["actual_price"] = actual_price
            print(f"Evaluated Decision at {decision['timestamp']}: predicted {decision['prediction']}, "
                  f"actual {decision['actual_price']}, action: {decision['action']}")
                        # Determine the actual action based on the actual price
            if actual_price is not None:
                if decision["action"] == "buy":
                    y_pred.append(1)  # Predicted buy
                    y_true.append(1 if actual_price > decision["current_price"] else 0)  # Actual buy if price increased
                elif decision["action"] == "sell":
                    y_pred.append(0)  # Predicted sell
                    y_true.append(0 if actual_price < decision["current_price"] else 1)  # Actual sell if price decreased

        # Calculate confusion matrix
        cm = confusion_matrix(y_true, y_pred, labels=[1, 0])
        disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=["Buy", "Sell"])
        disp.plot()
        plt.title("Confusion Matrix of Trading Decisions")
        plt.show()

        # Print confusion matrix
        print("Confusion Matrix:")
        print(cm)

# %% [markdown]
# #### BackTesting

# %%
class BackTesting:
    def __init__(self, framework):
        self.framework = framework
        if framework == 'pytorch':
            self.device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
            print("CUDA Available:", torch.cuda.is_available())
            self.data_structure = self.initialize_pytorch_structure()
        else:
            self.data_structure = self.initialize_other_structure()

    def initialize_pytorch_structure(self):
        return {"data": torch.tensor([])}

    def initialize_other_structure(self):
        return {"data": np.array([])}

    def run_backtest(self, data_file_path):
        model = Model(input_size=9, hidden_size=50, output_size=1, num_layers=1, device=self.device)
        model.load_data(data_file_path)
        model.prepare_data(time_step=60)
        model.create_datasets()
        model.train(model.X_train, model.y_train, model.X_test, model.y_test, epochs=100, batch_size=16, learning_rate=0.001, patience=8)
        self.predictions, self.y_test = model.evaluate(model.X_test, model.y_test, model.target_scaler)

        # Load YAML configuration
        config = load_config("./config.yaml")

        # Create signals
        buy_signal_config = config["signals"]["buy_signal"]
        sell_signal_config = config["signals"]["sell_signal"]

        # Create strategy
        strategy = Strategy(config)

        strategy.X_test_df = model.X_test_df  # Pass the DataFrame to the strategy
        for i in range(len(model.X_test)):
            current_price = model.data['close'].iloc[int(0.8 * len(model.data)) + i]
            predicted_high = self.predictions[i][0]
            current_timestamp = model.data.index[int(0.8 * len(model.data)) + i]
            future_timestamp = model.data.index[int(0.8 * len(model.data)) + i + 1]

            signal = Signal(current_price, buy_signal_config, sell_signal_config)
            strategy.execute_trade(signal, future_timestamp, predicted_high, current_price)

        strategy.evaluate_decisions()  # Evaluate and print decisions

        performance_metrics = PerformanceMetrics(model.data, strategy)
        performance_metrics.calculate_performance_metrics()

# %% [markdown]
# #### PerformanceMetrics

# %%
class PerformanceMetrics:
    def __init__(self, data, strategy):
        self.data = data
        self.strategy = strategy
        self.portfolio_series = None
        self.portfolio_df = None
        self.trading_per_min = None
        self.total_minutes = None
        self.trading_minutes_per_day = None  

    def prepare_data(self):
        """Prepare the data for performance metrics calculation."""
        try:
            self.data.index = pd.to_datetime(self.data.index)
            self.data['date'] = self.data.index

            # Debug: Print the start and end dates of the data index
            logging.debug(f"Data index start: {self.data.index[0]}, end: {self.data.index[-1]}")

            # Create portfolio_series with the appropriate frequency
            self.portfolio_series = pd.Series(
                self.strategy.portfolio_value,
                index=pd.date_range(
                    start=self.data.index[-len(self.strategy.portfolio_value)],
                    periods=len(self.strategy.portfolio_value),
                    freq='min'  # Set the appropriate frequency
                )
            )

            # Debug: Print the length of self.portfolio_series
            logging.debug(f"Length of self.portfolio_series: {len(self.portfolio_series)}")

            # Debug: Print the first few entries of self.portfolio_series
            logging.debug(f"First few entries of self.portfolio_series:\n{self.portfolio_series.head()}")

        except Exception as e:
            logging.error(f"Error in prepare_data: {e}")

        print(self.portfolio_series)
        

    def calculate_trading_minutes_per_day(self):
        """Calculate the number of trading days, total trading minutes per day, and the average trading minutes per day."""
        try:
            # Ensure portfolio_series is available and has a DateTimeIndex
            if self.portfolio_series is None or not isinstance(self.portfolio_series.index, pd.DatetimeIndex):
                raise ValueError("portfolio_series is not set or does not have a DateTimeIndex")
    
            # Group by date and count the number of minutes traded each day
            total_num_trading = self.portfolio_series.groupby(self.portfolio_series.index.date).size()
    
            # Calculate the total number of trading days
            num_trading_days = total_num_trading.size
            logging.info(f"Total Number of Trading Days: {num_trading_days}")
    
            # Calculate the average number of trading minutes per day
            average_trading_minutes_per_day = total_num_trading.mean()
            self.trading_minutes_per_day = average_trading_minutes_per_day
            logging.info(f"Average Trading Minutes Per Day: {self.trading_minutes_per_day:.2f}")
    
            # Log the number of trades (minutes) for each particular date
            for date, minutes in total_num_trading.items():
                logging.debug(f"Date: {date}, Minutes: {minutes}")
    
        except Exception as e:
            logging.error(f"Error in calculate_trading_minutes_per_day: {e}")




    def calculate_hit_ratio(self):
        """Calculate the hit ratio of the strategy."""
        try:
            if self.strategy.total_trades > 0:
                hit_ratio = (self.strategy.winning_trades / self.strategy.total_trades) * 100
                logging.debug(f"Hit Ratio: {hit_ratio}")
                return hit_ratio
            return 0
        except Exception as e:
            logging.error(f"Error in calculate_hit_ratio: {e}")
            return np.nan

    def calculate_strategy_gain(self):
        """Calculate the strategy gain."""
        try:
            strategy_gain = (self.strategy.portfolio_value[-1] - self.strategy.initial_cash) / self.strategy.initial_cash * 100
            logging.debug(f"Strategy Gain: {strategy_gain}")
            return strategy_gain
        except Exception as e:
            logging.error(f"Error in calculate_strategy_gain: {e}")
            return np.nan

    def plot_portfolio_value(self):
        """Plot the portfolio value over time."""
        try:
            plt.plot(self.portfolio_series.index, self.portfolio_series, label='Portfolio Value')
            plt.xlabel('Date')
            plt.ylabel('Portfolio Value (USD)')
            plt.title('Portfolio Value Over Time')
            plt.legend()
            plt.show()
        except Exception as e:
            logging.error(f"Error in plot_portfolio_value: {e}")

    def convert_to_dataframe(self):
        """Convert the portfolio series to a DataFrame."""
        try:
            self.portfolio_df = pd.DataFrame(self.portfolio_series)
            self.portfolio_df['returns'] = self.portfolio_df[0].pct_change()
        except Exception as e:
            logging.error(f"Error in convert_to_dataframe: {e}")

    def calculate_max_drawdown(self):
        """Calculate the maximum drawdown."""
        try:
            max_drawdown = ffn.calc_max_drawdown(self.portfolio_series)
            logging.debug(f"Maximum Drawdown: {max_drawdown}")
            return max_drawdown
        except Exception as e:
            logging.error(f"Error in calculate_max_drawdown: {e}")
            return np.nan

    def calculate_sharpe_ratio(self, risk_free_rate=0.01):
        """Calculate the Sharpe Ratio."""
        try:
            # Calculate the expected portfolio return (Rx)
            minute_returns = self.portfolio_df['returns'].dropna()
            expected_portfolio_return = minute_returns.mean()
            logging.debug(f"Expected Portfolio Return (Rx): {expected_portfolio_return}")

            # Calculate the standard deviation of portfolio return (StdDev Rx)
            portfolio_volatility = minute_returns.std()
            logging.debug(f"Standard Deviation of Portfolio Return (StdDev Rx): {portfolio_volatility}")

            # Calculate the Sharpe Ratio
            sharpe_ratio = (expected_portfolio_return - risk_free_rate) / portfolio_volatility if portfolio_volatility != 0 else np.nan
            logging.debug(f"Risk-Free Rate (Rf): {risk_free_rate}, Sharpe Ratio: {sharpe_ratio}")

            return sharpe_ratio
        except Exception as e:
            logging.error(f"Error in calculate_sharpe_ratio: {e}")
            return np.nan
            
    def calculate_sortino_ratio(self, returns, risk_free_rate=0.0001):
        """Calculate the Sortino Ratio."""
        try:
            # Calculate the average return of the portfolio (Rp)
            average_return = returns.mean()
            logging.debug(f"Average Return (Rp): {average_return}")

            # Target rate of return (T) is the risk-free rate
            target_return = risk_free_rate
            logging.debug(f"Target Rate of Return (T): {target_return}")

            # Calculate the downside deviation (Dd)
            downside_returns = returns[returns < target_return]
            downside_deviation = np.sqrt(np.mean(np.square(downside_returns - target_return)))
            logging.debug(f"Downside Deviation (Dd): {downside_deviation}")

            # Calculate the Sortino Ratio
            sortino_ratio = (average_return - target_return) / downside_deviation if downside_deviation != 0 else np.nan
            logging.debug(f"Sortino Ratio: {sortino_ratio}")

            return sortino_ratio
        except Exception as e:
            logging.error(f"Error in calculate_sortino_ratio: {e}")
            return np.nan
        
    def compare_with_buy_and_hold(self, initial_cash, train_size, trading_days):
        """Compare the trading strategy with a Buy and Hold strategy."""
        try:
            # Buy and Hold Strategy
            buy_and_hold_value = [initial_cash]
            for price in self.data['close'].iloc[train_size:train_size + trading_days]:
                buy_and_hold_value.append(buy_and_hold_value[-1] * (1 + price / self.data['close'].iloc[train_size] - 1))

            # Convert to Series
            trading_strategy_series = pd.Series(self.strategy.portfolio_value)
            buy_and_hold_series = pd.Series(buy_and_hold_value[1:])

            # Calculate the absolute difference between the two strategies
            absolute_difference = trading_strategy_series - buy_and_hold_series

            # Plotting the results
            plt.figure(figsize=(12, 6))
            plt.plot(trading_strategy_series, label='Trading Strategy', marker='o')
            plt.plot(buy_and_hold_series, label='Buy and Hold', marker='o')
            plt.plot(absolute_difference, label='Absolute Difference', marker='o', linestyle='--')
            plt.title('Trading Strategy vs. Buy and Hold Performance')
            plt.xlabel('Time Period')
            plt.ylabel('Portfolio Value')
            plt.legend()
            plt.grid()
            plt.show()

            # The final values for comparison
            print("Final Trading Strategy Value:", trading_strategy_series.iloc[-1])
            print("Final Buy and Hold Value:", buy_and_hold_series.iloc[-1])
            print("Absolute Difference:", absolute_difference.iloc[-1])
        except Exception as e:
            logging.error(f"Error in compare_with_buy_and_hold: {e}")
            

    def calculate_performance_metrics(self):
        """Calculate and print all performance metrics."""
        self.prepare_data()
        self.calculate_trading_minutes_per_day()
        self.convert_to_dataframe()

        hit_ratio = self.calculate_hit_ratio()
        strategy_gain = self.calculate_strategy_gain()
        max_drawdown = self.calculate_max_drawdown()
        sharpe_ratio = self.calculate_sharpe_ratio()
        sortino_ratio = self.calculate_sortino_ratio(self.portfolio_df['returns'].dropna())

        # logging.debug('portfolio_series')
        # logging.debug(self.portfolio_series)

        print(f"Final portfolio value: ${self.strategy.portfolio_value[-1]:.2f}")
        print(f"Hit Ratio: {hit_ratio:.2f}%")
        print(f"Strategy Gain: {strategy_gain:.2f}%")
        print(f"Maximum Drawdown: {max_drawdown:.4%}" if max_drawdown is not None else "Maximum Drawdown: N/A")
        print(f"Sharpe Ratio: {sharpe_ratio:.2f}")
        print(f"Sortino Ratio: {sortino_ratio:.2f}")

        self.plot_portfolio_value()
        self.compare_with_buy_and_hold(self.strategy.initial_cash, train_size=0, trading_days=len(self.portfolio_series))

# %% [markdown]
# #### Model

# %%
class Model:
    def __init__(self, input_size, hidden_size, output_size, num_layers, device):
        self.device = device
        self.model = self.LSTMModel(input_size, hidden_size, output_size, num_layers, device).to(device)
        self.feature_scaler = MinMaxScaler(feature_range=(0, 1))
        self.target_scaler = MinMaxScaler(feature_range=(0, 1))

    class LSTMModel(nn.Module):
        def __init__(self, input_size, hidden_size, output_size, num_layers, device):
            super(Model.LSTMModel, self).__init__()
            self.hidden_size = hidden_size
            self.num_layers = num_layers
            self.device = device
            self.lstm = nn.LSTM(input_size, hidden_size, num_layers, batch_first=True)
            self.fc = nn.Linear(hidden_size, output_size)

        def forward(self, x):
            h0 = torch.zeros(self.num_layers, x.size(0), self.hidden_size).to(self.device)
            c0 = torch.zeros(self.num_layers, x.size(0), self.hidden_size).to(self.device)
            out, _ = self.lstm(x, (h0, c0))
            out = self.fc(out[:, -1, :])
            return out

    def load_data(self, file_path):
        self.data = pd.read_csv(file_path, parse_dates=['timestamp'], index_col='timestamp').head(8000)
        self.data['log_return'] = np.log(self.data['close'] / self.data['close'].shift(1))
        self.data['Next_High'] = self.data['high'].shift(-1)
        self.data['Return'] = self.data['close'].pct_change()
        self.data['Volatility'] = self.data['Return'].rolling(window=5).std()
        self.data['High_Low_Range'] = (self.data['high'] - self.data['low']) / self.data['low']
        self.data['Prev_Close_Rel_High'] = (self.data['close'].shift(1) - self.data['high']) / self.data['high']
        self.data.dropna(inplace=True)
        return self.data

    def prepare_data(self, time_step=60):
        self.time_step = time_step
        self.features = self.data[['open', 'high', 'low', 'close', 'volume', 'Return', 'Volatility', 'High_Low_Range', 'Prev_Close_Rel_High']].values
        self.targets = self.data['Next_High'].values
        self.features = self.feature_scaler.fit_transform(self.features)
        self.targets = self.target_scaler.fit_transform(self.targets.reshape(-1, 1))

    def create_datasets(self):
        X, y = [], []
        for i in range(len(self.features) - self.time_step):
            X.append(self.features[i:i + self.time_step])
            y.append(self.targets[i + self.time_step])
        X, y = np.array(X), np.array(y)
        split = int(0.8 * len(X))
        self.X_train = torch.tensor(X[:split], dtype=torch.float32)
        self.X_test = torch.tensor(X[split:], dtype=torch.float32)
        self.y_train = torch.tensor(y[:split], dtype=torch.float32)
        self.y_test = torch.tensor(y[split:], dtype=torch.float32)

        # Extract timestamps for the test set
        self.timestamps = self.data.index[split + self.time_step:]
        X_test_numpy = self.X_test.numpy()
        X_test_flat = X_test_numpy.reshape(-1, X_test_numpy.shape[-1])

        # Inverse transform the flattened X_test values
        X_test_flat_original = self.feature_scaler.inverse_transform(X_test_flat)

        # Repeat the timestamps to match the flattened shape
        timestamps_repeated = np.repeat(self.timestamps, self.X_test.shape[1])
        timestamps_repeated = timestamps_repeated[:X_test_flat_original.shape[0]]  # Ensure the lengths match

        # Create DataFrame with the inverse transformed X_test values and repeated timestamps
        self.X_test_df = pd.DataFrame(X_test_flat_original, columns=['open', 'high', 'low', 'close', 'volume', 'Return', 'Volatility', 'High_Low_Range', 'Prev_Close_Rel_High'], index=timestamps_repeated)

    def train(self, X_train, y_train, X_test, y_test, epochs, batch_size, learning_rate, patience):
        criterion = nn.MSELoss()
        optimizer = optim.Adam(self.model.parameters(), lr=learning_rate)
        train_loader = torch.utils.data.DataLoader(dataset=list(zip(X_train, y_train)), batch_size=batch_size, shuffle=True)
        best_val_loss = float('inf')
        epochs_without_improvement = 0

        for epoch in range(epochs):
            self.model.train()
            epoch_loss = 0
            for features, labels in train_loader:
                features, labels = features.to(self.device), labels.to(self.device)
                optimizer.zero_grad()
                outputs = self.model(features)
                loss = criterion(outputs, labels)
                loss.backward()
                optimizer.step()
                epoch_loss += loss.item()

            avg_epoch_loss = epoch_loss / len(train_loader)
            self.model.eval()
            with torch.no_grad():
                X_val = X_test.to(self.device)
                y_val = y_test.to(self.device)
                val_loss = criterion(self.model(X_val), y_val).item()

            if val_loss < best_val_loss:
                best_val_loss = val_loss
                epochs_without_improvement = 0
                torch.save(self.model.state_dict(), 'lstm_model.pth')
            else:
                epochs_without_improvement += 1
                if epochs_without_improvement >= patience:
                    break

    def evaluate(self, X_test, y_test, target_scaler):
        self.model.eval()
        with torch.no_grad():
            X_test = X_test.to(self.device)
            predictions = self.model(X_test).cpu().numpy()
            y_test = y_test.numpy()
        predictions = target_scaler.inverse_transform(predictions)
        y_test = target_scaler.inverse_transform(y_test)

        plt.plot(y_test, label='Actual')
        plt.plot(predictions, label='Predicted')
        plt.legend()
        plt.show()
        return predictions, y_test




# Usage
if __name__ == '__main__':
    bt = BackTesting('pytorch')
    bt.run_backtest('../../datasets/FIXED_EODHD_EURUSD_HISTORICAL_2019_2024_1min.csv')
# Out:
# CUDA Available: True
# Evaluated Decision at 2019-01-08 11:16:00: predicted 1.1444905996322632, actual None, action: buy
# Evaluated Decision at 2019-01-08 11:17:00: predicted 1.1444038152694702, actual None, action: sell
# Evaluated Decision at 2019-01-08 11:24:00: predicted 1.144516110420227, actual 1.1436599493026733, action: buy
# Evaluated Decision at 2019-01-08 11:25:00: predicted 1.1443952322006226, actual 1.1437699794769287, action: exit
# Evaluated Decision at 2019-01-08 11:26:00: predicted 1.1444069147109985, actual 1.1437100172042847, action: buy
# Evaluated Decision at 2019-01-08 11:27:00: predicted 1.1445372104644775, actual 1.1436799764633179, action: sell
# Evaluated Decision at 2019-01-08 11:28:00: predicted 1.1444891691207886, actual 1.1435099840164185, action: buy
# Evaluated Decision at 2019-01-08 11:29:00: predicted 1.1443520784378052, actual 1.143530011177063, action: exit
# Evaluated Decision at 2019-01-08 11:30:00: predicted 1.1444413661956787, actual 1.1434099674224854, action: buy
# Evaluated Decision at 2019-01-08 11:31:00: predicted 1.144492506980896, actual 1.1434299945831299, action: buy
# Evaluated Decision at 2019-01-08 11:32:00: predicted 1.1444520950317383, actual 1.1434600353240967, action: sell
# Evaluated Decision at 2019-01-08 11:47:00: predicted 1.1441890001296997, actual 1.1440399885177612, action: buy
# Evaluated Decision at 2019-01-08 11:48:00: predicted 1.144063949584961, actual 1.144089937210083, action: buy
# Evaluated Decision at 2019-01-08 11:49:00: predicted 1.1442883014678955, actual 1.1438199281692505, action: buy
# Evaluated Decision at 2019-01-08 11:50:00: predicted 1.1443523168563843, actual 1.143779993057251, action: buy
# Evaluated Decision at 2019-01-08 11:51:00: predicted 1.1441954374313354, actual 1.1435600519180298, action: buy
# Evaluated Decision at 2019-01-08 11:52:00: predicted 1.1442170143127441, actual 1.1437699794769287, action: buy
# Evaluated Decision at 2019-01-08 11:53:00: predicted 1.144204020500183, actual 1.144029974937439, action: sell
# Evaluated Decision at 2019-01-08 11:58:00: predicted 1.144309401512146, actual 1.143970012664795, action: buy
# Evaluated Decision at 2019-01-08 11:59:00: predicted 1.1440150737762451, actual 1.1442400217056274, action: exit
# Evaluated Decision at 2019-01-08 12:02:00: predicted 1.144430160522461, actual 1.1443800926208496, action: buy
# Evaluated Decision at 2019-01-08 12:03:00: predicted 1.144379734992981, actual 1.1442699432373047, action: buy
# Evaluated Decision at 2019-01-08 12:04:00: predicted 1.1442255973815918, actual 1.1441700458526611, action: sell
# Evaluated Decision at 2019-01-08 12:05:00: predicted 1.1441954374313354, actual 1.1443099975585938, action: buy
# Evaluated Decision at 2019-01-08 12:06:00: predicted 1.144195795059204, actual 1.1443499326705933, action: buy
# Evaluated Decision at 2019-01-08 12:07:00: predicted 1.1444413661956787, actual 1.1443400382995605, action: buy
# Evaluated Decision at 2019-01-08 12:08:00: predicted 1.1443638801574707, actual 1.1443899869918823, action: buy
# Evaluated Decision at 2019-01-08 12:09:00: predicted 1.1444942951202393, actual 1.1444299221038818, action: buy
# Evaluated Decision at 2019-01-08 12:10:00: predicted 1.14451265335083, actual 1.144439935684204, action: buy
# Evaluated Decision at 2019-01-08 12:11:00: predicted 1.1444823741912842, actual 1.1444299221038818, action: buy
# Evaluated Decision at 2019-01-08 12:12:00: predicted 1.144585132598877, actual 1.1446000337600708, action: buy
# Evaluated Decision at 2019-01-08 12:13:00: predicted 1.1445465087890625, actual 1.1445800065994263, action: buy
# Evaluated Decision at 2019-01-08 12:14:00: predicted 1.1443979740142822, actual 1.1444900035858154, action: sell
# Evaluated Decision at 2019-01-08 12:15:00: predicted 1.144361138343811, actual 1.1444599628448486, action: buy
# Evaluated Decision at 2019-01-08 12:16:00: predicted 1.144239902496338, actual 1.1445900201797485, action: buy
# Evaluated Decision at 2019-01-08 12:17:00: predicted 1.1444082260131836, actual 1.1446499824523926, action: buy
# Evaluated Decision at 2019-01-08 12:18:00: predicted 1.1444072723388672, actual 1.1445499658584595, action: sell
# Evaluated Decision at 2019-01-08 12:19:00: predicted 1.1444560289382935, actual 1.1447200775146484, action: buy
# Evaluated Decision at 2019-01-08 12:20:00: predicted 1.1446740627288818, actual 1.144860029220581, action: buy
# Evaluated Decision at 2019-01-08 12:21:00: predicted 1.1446572542190552, actual 1.1448700428009033, action: buy
# Evaluated Decision at 2019-01-08 12:22:00: predicted 1.1445364952087402, actual 1.1448800563812256, action: sell
# Evaluated Decision at 2019-01-08 12:24:00: predicted 1.1446795463562012, actual 1.1444799900054932, action: buy
# Evaluated Decision at 2019-01-08 12:25:00: predicted 1.145082712173462, actual 1.144469976425171, action: buy
# Evaluated Decision at 2019-01-08 12:26:00: predicted 1.1454122066497803, actual 1.1445599794387817, action: buy
# Evaluated Decision at 2019-01-08 12:27:00: predicted 1.1450656652450562, actual 1.144569993019104, action: buy
# Evaluated Decision at 2019-01-08 12:28:00: predicted 1.145108699798584, actual 1.14451003074646, action: buy
# Evaluated Decision at 2019-01-08 12:29:00: predicted 1.1452275514602661, actual 1.144450068473816, action: buy
# Evaluated Decision at 2019-01-08 12:30:00: predicted 1.1451504230499268, actual 1.1444799900054932, action: buy
# Evaluated Decision at 2019-01-08 12:31:00: predicted 1.1451667547225952, actual 1.144860029220581, action: buy
# Evaluated Decision at 2019-01-08 12:32:00: predicted 1.1451152563095093, actual 1.1448500156402588, action: buy
# Evaluated Decision at 2019-01-08 12:33:00: predicted 1.1450883150100708, actual 1.1447299718856812, action: buy
# Evaluated Decision at 2019-01-08 12:34:00: predicted 1.1451849937438965, actual 1.1446900367736816, action: buy
# Evaluated Decision at 2019-01-08 12:35:00: predicted 1.14511239528656, actual 1.1446800231933594, action: buy
# Evaluated Decision at 2019-01-08 12:36:00: predicted 1.1452240943908691, actual 1.1444799900054932, action: buy
# Evaluated Decision at 2019-01-08 12:37:00: predicted 1.1452099084854126, actual 1.1446999311447144, action: sell
# Evaluated Decision at 2019-01-08 12:38:00: predicted 1.145275354385376, actual 1.1445800065994263, action: buy
# Evaluated Decision at 2019-01-08 12:39:00: predicted 1.1452407836914062, actual 1.144569993019104, action: buy
# Evaluated Decision at 2019-01-08 12:40:00: predicted 1.1452109813690186, actual 1.14451003074646, action: sell
# Evaluated Decision at 2019-01-08 12:41:00: predicted 1.1454108953475952, actual 1.144629955291748, action: buy
# Evaluated Decision at 2019-01-08 12:42:00: predicted 1.1453217267990112, actual 1.1445900201797485, action: buy
# Evaluated Decision at 2019-01-08 12:43:00: predicted 1.1453769207000732, actual 1.1445000171661377, action: buy
# Evaluated Decision at 2019-01-08 12:44:00: predicted 1.1453739404678345, actual 1.1445499658584595, action: buy
# Evaluated Decision at 2019-01-08 12:45:00: predicted 1.1452841758728027, actual 1.1445000171661377, action: buy
# Evaluated Decision at 2019-01-08 12:46:00: predicted 1.1453745365142822, actual 1.1442500352859497, action: buy
# Evaluated Decision at 2019-01-08 12:47:00: predicted 1.1453220844268799, actual 1.1439100503921509, action: buy
# Evaluated Decision at 2019-01-08 12:48:00: predicted 1.145246982574463, actual 1.1438699960708618, action: sell
# Evaluated Decision at 2019-01-08 12:49:00: predicted 1.145355224609375, actual 1.144129991531372, action: buy
# Evaluated Decision at 2019-01-08 12:50:00: predicted 1.145397663116455, actual 1.144089937210083, action: buy
# Evaluated Decision at 2019-01-08 12:51:00: predicted 1.1455397605895996, actual 1.144219994544983, action: buy
# Evaluated Decision at 2019-01-08 12:52:00: predicted 1.1452035903930664, actual 1.1442500352859497, action: sell
# Evaluated Decision at 2019-01-08 13:23:00: predicted 1.144839882850647, actual 1.1447200775146484, action: buy
# Evaluated Decision at 2019-01-08 13:24:00: predicted 1.144841194152832, actual 1.1446599960327148, action: buy
# Evaluated Decision at 2019-01-08 13:25:00: predicted 1.1445870399475098, actual 1.1445000171661377, action: exit
# Evaluated Decision at 2019-01-08 13:31:00: predicted 1.1446901559829712, actual 1.144779920578003, action: buy
# Evaluated Decision at 2019-01-08 13:32:00: predicted 1.144755244255066, actual 1.1447499990463257, action: buy
# Evaluated Decision at 2019-01-08 13:33:00: predicted 1.1447975635528564, actual 1.1447200775146484, action: buy
# Evaluated Decision at 2019-01-08 13:34:00: predicted 1.144835114479065, actual 1.1447499990463257, action: sell
# Evaluated Decision at 2019-01-08 13:35:00: predicted 1.1450152397155762, actual 1.1453499794006348, action: buy
# Evaluated Decision at 2019-01-08 13:36:00: predicted 1.1448038816452026, actual 1.1455700397491455, action: buy
# Evaluated Decision at 2019-01-08 13:37:00: predicted 1.1447423696517944, actual 1.1454999446868896, action: buy
# Evaluated Decision at 2019-01-08 13:38:00: predicted 1.144689679145813, actual 1.1452499628067017, action: buy
# Evaluated Decision at 2019-01-08 13:39:00: predicted 1.144659161567688, actual 1.1453300714492798, action: buy
# Evaluated Decision at 2019-01-08 13:40:00: predicted 1.144671082496643, actual 1.145319938659668, action: buy
# Evaluated Decision at 2019-01-08 13:41:00: predicted 1.1445831060409546, actual 1.145319938659668, action: exit
# Evaluated Decision at 2019-01-08 13:58:00: predicted 1.1442229747772217, actual 1.1454800367355347, action: buy
# Evaluated Decision at 2019-01-08 13:59:00: predicted 1.1442389488220215, actual 1.1454499959945679, action: buy
# Evaluated Decision at 2019-01-08 14:00:00: predicted 1.1442019939422607, actual 1.1454999446868896, action: buy
# Evaluated Decision at 2019-01-08 14:01:00: predicted 1.1442221403121948, actual 1.1459299325942993, action: buy
# Evaluated Decision at 2019-01-08 14:02:00: predicted 1.1442080736160278, actual 1.1455700397491455, action: buy
# Evaluated Decision at 2019-01-08 14:03:00: predicted 1.1441986560821533, actual 1.145319938659668, action: buy
# Evaluated Decision at 2019-01-08 14:04:00: predicted 1.1442652940750122, actual 1.1454399824142456, action: buy
# Evaluated Decision at 2019-01-08 14:05:00: predicted 1.1442375183105469, actual 1.1454999446868896, action: buy
# Evaluated Decision at 2019-01-08 14:06:00: predicted 1.144311547279358, actual 1.1452800035476685, action: buy
# Evaluated Decision at 2019-01-08 14:07:00: predicted 1.1441466808319092, actual 1.1452200412750244, action: sell
# Evaluated Decision at 2019-01-08 14:11:00: predicted 1.1442830562591553, actual 1.1451199054718018, action: buy
# Evaluated Decision at 2019-01-08 14:12:00: predicted 1.1442437171936035, actual 1.1449799537658691, action: sell
# Evaluated Decision at 2019-01-08 14:13:00: predicted 1.1443202495574951, actual 1.1450700759887695, action: buy
# Evaluated Decision at 2019-01-08 14:14:00: predicted 1.1442598104476929, actual 1.1452200412750244, action: exit
# Evaluated Decision at 2019-01-08 14:26:00: predicted 1.1442257165908813, actual 1.1449600458145142, action: buy
# Evaluated Decision at 2019-01-08 14:27:00: predicted 1.144297480583191, actual 1.144860029220581, action: buy
# Evaluated Decision at 2019-01-08 14:28:00: predicted 1.1442979574203491, actual 1.1448899507522583, action: buy
# Evaluated Decision at 2019-01-08 14:29:00: predicted 1.144231915473938, actual 1.1448700428009033, action: buy
# Evaluated Decision at 2019-01-08 14:30:00: predicted 1.1441640853881836, actual 1.1447099447250366, action: buy
# Evaluated Decision at 2019-01-08 14:31:00: predicted 1.144199252128601, actual 1.1446800231933594, action: buy
# Evaluated Decision at 2019-01-08 14:32:00: predicted 1.1442135572433472, actual 1.1446999311447144, action: sell
# Evaluated Decision at 2019-01-08 14:49:00: predicted 1.1441556215286255, actual 1.1448099613189697, action: buy
# Evaluated Decision at 2019-01-08 14:50:00: predicted 1.144097924232483, actual 1.1448099613189697, action: sell
# Evaluated Decision at 2019-01-08 14:52:00: predicted 1.1441289186477661, actual 1.144670009613037, action: buy
# Evaluated Decision at 2019-01-08 14:53:00: predicted 1.1441274881362915, actual 1.1445900201797485, action: buy
# Evaluated Decision at 2019-01-08 14:54:00: predicted 1.144047737121582, actual 1.1445599794387817, action: exit
# Evaluated Decision at 2019-01-08 15:18:00: predicted 1.143757939338684, actual 1.144260048866272, action: buy
# Evaluated Decision at 2019-01-08 15:19:00: predicted 1.1437383890151978, actual 1.144320011138916, action: sell
# Evaluated Decision at 2019-01-08 15:26:00: predicted 1.1438651084899902, actual 1.1441999673843384, action: buy
# Evaluated Decision at 2019-01-08 15:27:00: predicted 1.1438244581222534, actual 1.1441500186920166, action: buy
# Evaluated Decision at 2019-01-08 15:28:00: predicted 1.143872618675232, actual 1.1441400051116943, action: buy
# Evaluated Decision at 2019-01-08 15:29:00: predicted 1.1437911987304688, actual 1.1441599130630493, action: sell
# Evaluated Decision at 2019-01-08 15:30:00: predicted 1.143811583518982, actual 1.144219994544983, action: buy
# Evaluated Decision at 2019-01-08 15:31:00: predicted 1.14375901222229, actual 1.1442699432373047, action: exit
# Evaluated Decision at 2019-01-08 15:34:00: predicted 1.143743634223938, actual 1.1443300247192383, action: buy
# Evaluated Decision at 2019-01-08 15:35:00: predicted 1.1437969207763672, actual 1.144320011138916, action: buy
# Evaluated Decision at 2019-01-08 15:36:00: predicted 1.1438394784927368, actual 1.144320011138916, action: buy
# Evaluated Decision at 2019-01-08 15:37:00: predicted 1.1438783407211304, actual 1.1443899869918823, action: sell
# Evaluated Decision at 2019-01-08 15:40:00: predicted 1.143881916999817, actual 1.144320011138916, action: buy
# Evaluated Decision at 2019-01-08 15:41:00: predicted 1.1438112258911133, actual 1.1442699432373047, action: sell
# Evaluated Decision at 2019-01-08 15:48:00: predicted 1.143996000289917, actual 1.1442699432373047, action: buy
# Evaluated Decision at 2019-01-08 15:49:00: predicted 1.1439485549926758, actual 1.1442300081253052, action: sell
# Evaluated Decision at 2019-01-08 15:51:00: predicted 1.1440056562423706, actual 1.1441199779510498, action: buy
# Evaluated Decision at 2019-01-08 15:52:00: predicted 1.144016146659851, actual 1.144129991531372, action: buy
# Evaluated Decision at 2019-01-08 15:53:00: predicted 1.144012689590454, actual 1.1441199779510498, action: buy
# Evaluated Decision at 2019-01-08 15:54:00: predicted 1.1440352201461792, actual 1.144129991531372, action: buy
# Evaluated Decision at 2019-01-08 15:55:00: predicted 1.1440110206604004, actual 1.144219994544983, action: buy
# Evaluated Decision at 2019-01-08 15:56:00: predicted 1.1440123319625854, actual 1.144219994544983, action: buy
# Evaluated Decision at 2019-01-08 15:57:00: predicted 1.1440232992172241, actual 1.1441800594329834, action: buy
# Evaluated Decision at 2019-01-08 15:58:00: predicted 1.1439417600631714, actual 1.144129991531372, action: sell
# Evaluated Decision at 2019-01-08 16:09:00: predicted 1.144074559211731, actual 1.1441900730133057, action: buy
# Evaluated Decision at 2019-01-08 16:10:00: predicted 1.144060730934143, actual 1.144129991531372, action: buy
# Evaluated Decision at 2019-01-08 16:11:00: predicted 1.1440329551696777, actual 1.1440600156784058, action: buy
# Evaluated Decision at 2019-01-08 16:12:00: predicted 1.1440523862838745, actual 1.1440199613571167, action: buy
# Evaluated Decision at 2019-01-08 16:13:00: predicted 1.1440777778625488, actual 1.1440199613571167, action: buy
# Evaluated Decision at 2019-01-08 16:14:00: predicted 1.1440623998641968, actual 1.1439399719238281, action: buy
# Evaluated Decision at 2019-01-08 16:15:00: predicted 1.1440669298171997, actual 1.1439399719238281, action: buy
# Evaluated Decision at 2019-01-08 16:16:00: predicted 1.1440670490264893, actual 1.1439200639724731, action: buy
# Evaluated Decision at 2019-01-08 16:17:00: predicted 1.1440117359161377, actual 1.1438300609588623, action: sell
# Evaluated Decision at 2019-01-08 16:44:00: predicted 1.143992304801941, actual 1.1438699960708618, action: buy
# Evaluated Decision at 2019-01-08 16:45:00: predicted 1.143908143043518, actual 1.1438699960708618, action: exit
# Evaluated Decision at 2019-01-08 16:47:00: predicted 1.1439975500106812, actual 1.1439800262451172, action: buy
# Evaluated Decision at 2019-01-08 16:48:00: predicted 1.1440355777740479, actual 1.143970012664795, action: buy
# Evaluated Decision at 2019-01-08 16:49:00: predicted 1.1439518928527832, actual 1.1439900398254395, action: buy
# Evaluated Decision at 2019-01-08 16:50:00: predicted 1.1439274549484253, actual 1.1440099477767944, action: buy
# Evaluated Decision at 2019-01-08 16:51:00: predicted 1.1439388990402222, actual 1.1439599990844727, action: buy
# Evaluated Decision at 2019-01-08 16:52:00: predicted 1.1439694166183472, actual 1.1439100503921509, action: buy
# Evaluated Decision at 2019-01-08 16:53:00: predicted 1.1439727544784546, actual 1.1439399719238281, action: buy
# Evaluated Decision at 2019-01-08 16:54:00: predicted 1.1439557075500488, actual 1.1438699960708618, action: exit
# Evaluated Decision at 2019-01-08 16:57:00: predicted 1.1439837217330933, actual 1.1440399885177612, action: buy
# Evaluated Decision at 2019-01-08 16:58:00: predicted 1.143975853919983, actual 1.1440800428390503, action: sell
# Evaluated Decision at 2019-01-08 17:00:00: predicted 1.1440703868865967, actual 1.144070029258728, action: buy
# Evaluated Decision at 2019-01-08 17:01:00: predicted 1.1441566944122314, actual 1.1441199779510498, action: buy
# Evaluated Decision at 2019-01-08 17:03:00: predicted 1.144119381904602, actual 1.1441199779510498, action: buy
# Evaluated Decision at 2019-01-08 17:04:00: predicted 1.1439729928970337, actual 1.144129991531372, action: sell
# Evaluated Decision at 2019-01-08 17:37:00: predicted 1.1438385248184204, actual 1.1440399885177612, action: buy
# Evaluated Decision at 2019-01-08 17:38:00: predicted 1.1438534259796143, actual 1.1440999507904053, action: buy
# Evaluated Decision at 2019-01-08 17:39:00: predicted 1.1438543796539307, actual 1.1440999507904053, action: sell
# Evaluated Decision at 2019-01-08 17:42:00: predicted 1.1438738107681274, actual 1.1440399885177612, action: buy
# Evaluated Decision at 2019-01-08 17:43:00: predicted 1.1439242362976074, actual 1.1439900398254395, action: buy
# Evaluated Decision at 2019-01-08 17:44:00: predicted 1.14402437210083, actual 1.1439499855041504, action: buy
# Evaluated Decision at 2019-01-08 17:45:00: predicted 1.1439532041549683, actual 1.1439900398254395, action: buy
# Evaluated Decision at 2019-01-08 17:46:00: predicted 1.1439599990844727, actual 1.1439800262451172, action: buy
# Evaluated Decision at 2019-01-08 17:47:00: predicted 1.144027590751648, actual 1.1439900398254395, action: buy
# Evaluated Decision at 2019-01-08 17:48:00: predicted 1.14397132396698, actual 1.1440000534057617, action: buy
# Evaluated Decision at 2019-01-08 17:49:00: predicted 1.1439697742462158, actual 1.1439900398254395, action: buy
# Evaluated Decision at 2019-01-08 17:50:00: predicted 1.1441487073898315, actual 1.143970012664795, action: buy
# Evaluated Decision at 2019-01-08 17:51:00: predicted 1.1441762447357178, actual 1.1439299583435059, action: buy
# Evaluated Decision at 2019-01-08 17:52:00: predicted 1.1442075967788696, actual 1.1439599990844727, action: buy
# Evaluated Decision at 2019-01-08 17:53:00: predicted 1.1442188024520874, actual 1.1439499855041504, action: buy
# Evaluated Decision at 2019-01-08 17:54:00: predicted 1.1442888975143433, actual 1.1439599990844727, action: buy
# Evaluated Decision at 2019-01-08 17:55:00: predicted 1.144361138343811, actual 1.1440099477767944, action: buy
# Evaluated Decision at 2019-01-08 17:56:00: predicted 1.1443393230438232, actual 1.1440999507904053, action: buy
# Evaluated Decision at 2019-01-08 17:57:00: predicted 1.144397258758545, actual 1.1441400051116943, action: buy
# Evaluated Decision at 2019-01-08 17:58:00: predicted 1.1444387435913086, actual 1.1439800262451172, action: buy
# Evaluated Decision at 2019-01-08 17:59:00: predicted 1.1444268226623535, actual 1.144070029258728, action: buy
# Evaluated Decision at 2019-01-08 18:00:00: predicted 1.1443942785263062, actual 1.1441199779510498, action: buy
# Evaluated Decision at 2019-01-08 18:01:00: predicted 1.1443870067596436, actual 1.1441500186920166, action: buy
# Evaluated Decision at 2019-01-08 18:02:00: predicted 1.144376277923584, actual 1.144029974937439, action: buy
# Evaluated Decision at 2019-01-08 18:03:00: predicted 1.144350290298462, actual 1.1440199613571167, action: buy
# Evaluated Decision at 2019-01-08 18:04:00: predicted 1.1443496942520142, actual 1.1440600156784058, action: buy
# Evaluated Decision at 2019-01-08 18:05:00: predicted 1.1443787813186646, actual 1.1440600156784058, action: buy
# Evaluated Decision at 2019-01-08 18:06:00: predicted 1.144381046295166, actual 1.1440600156784058, action: sell
# Evaluated Decision at 2019-01-08 18:07:00: predicted 1.144478440284729, actual 1.1440600156784058, action: buy
# Evaluated Decision at 2019-01-08 18:08:00: predicted 1.1444827318191528, actual 1.1440600156784058, action: buy
# Evaluated Decision at 2019-01-08 18:09:00: predicted 1.1444748640060425, actual 1.1440600156784058, action: sell
# Evaluated Decision at 2019-01-08 18:11:00: predicted 1.1445149183273315, actual 1.1441999673843384, action: buy
# Evaluated Decision at 2019-01-08 18:12:00: predicted 1.144533634185791, actual 1.1441700458526611, action: buy
# Evaluated Decision at 2019-01-08 18:14:00: predicted 1.1445852518081665, actual 1.1443499326705933, action: buy
# Evaluated Decision at 2019-01-08 18:15:00: predicted 1.1445841789245605, actual 1.144320011138916, action: buy
# Evaluated Decision at 2019-01-08 18:16:00: predicted 1.1446415185928345, actual 1.1441700458526611, action: buy
# Evaluated Decision at 2019-01-08 18:17:00: predicted 1.144600749015808, actual 1.1440399885177612, action: buy
# Evaluated Decision at 2019-01-08 18:18:00: predicted 1.1446378231048584, actual 1.1440199613571167, action: buy
# Evaluated Decision at 2019-01-08 18:19:00: predicted 1.1446298360824585, actual 1.144029974937439, action: buy
# Evaluated Decision at 2019-01-08 18:20:00: predicted 1.1445871591567993, actual 1.1440399885177612, action: buy
# Evaluated Decision at 2019-01-08 18:21:00: predicted 1.1446226835250854, actual 1.1440399885177612, action: buy
# Evaluated Decision at 2019-01-08 18:23:00: predicted 1.1446174383163452, actual 1.1440399885177612, action: buy
# Evaluated Decision at 2019-01-08 18:24:00: predicted 1.1446032524108887, actual 1.1440399885177612, action: sell
# Evaluated Decision at 2019-01-08 18:26:00: predicted 1.1446878910064697, actual 1.1440399885177612, action: buy
# Evaluated Decision at 2019-01-08 18:27:00: predicted 1.1447416543960571, actual 1.1440500020980835, action: buy
# Evaluated Decision at 2019-01-08 18:28:00: predicted 1.144819974899292, actual 1.1440399885177612, action: buy
# Evaluated Decision at 2019-01-08 18:29:00: predicted 1.1447964906692505, actual 1.1440399885177612, action: buy
# Evaluated Decision at 2019-01-08 18:30:00: predicted 1.1448146104812622, actual 1.1440500020980835, action: buy
# Evaluated Decision at 2019-01-08 18:31:00: predicted 1.1448655128479004, actual 1.1440399885177612, action: buy
# Evaluated Decision at 2019-01-08 18:32:00: predicted 1.1448731422424316, actual 1.144070029258728, action: buy
# Evaluated Decision at 2019-01-08 18:33:00: predicted 1.144980788230896, actual 1.1440399885177612, action: buy
# Evaluated Decision at 2019-01-08 18:34:00: predicted 1.1450196504592896, actual 1.1440399885177612, action: buy
# Evaluated Decision at 2019-01-08 18:35:00: predicted 1.1448804140090942, actual 1.1440399885177612, action: buy
# Evaluated Decision at 2019-01-08 18:36:00: predicted 1.1448487043380737, actual 1.1440399885177612, action: buy
# Evaluated Decision at 2019-01-08 18:37:00: predicted 1.1448936462402344, actual 1.144029974937439, action: buy
# Evaluated Decision at 2019-01-08 18:38:00: predicted 1.144935131072998, actual 1.144029974937439, action: buy
# Evaluated Decision at 2019-01-08 18:39:00: predicted 1.144932746887207, actual 1.1438300609588623, action: buy
# Evaluated Decision at 2019-01-08 18:40:00: predicted 1.1449320316314697, actual 1.1440600156784058, action: buy
# Evaluated Decision at 2019-01-08 18:41:00: predicted 1.144938588142395, actual 1.1442099809646606, action: buy
# Evaluated Decision at 2019-01-08 18:42:00: predicted 1.145059585571289, actual 1.1440199613571167, action: buy
# Evaluated Decision at 2019-01-08 18:43:00: predicted 1.1450830698013306, actual 1.1439200639724731, action: buy
# Evaluated Decision at 2019-01-08 18:44:00: predicted 1.1452558040618896, actual 1.1438100337982178, action: buy
# Evaluated Decision at 2019-01-08 18:45:00: predicted 1.1454710960388184, actual 1.1440099477767944, action: buy
# Evaluated Decision at 2019-01-08 18:46:00: predicted 1.1455118656158447, actual 1.1440399885177612, action: buy
# Evaluated Decision at 2019-01-08 18:47:00: predicted 1.1455425024032593, actual 1.143880009651184, action: buy
# Evaluated Decision at 2019-01-08 18:48:00: predicted 1.145465612411499, actual 1.1437699794769287, action: buy
# Evaluated Decision at 2019-01-08 18:49:00: predicted 1.145674705505371, actual 1.1439200639724731, action: buy
# Evaluated Decision at 2019-01-08 18:50:00: predicted 1.1455408334732056, actual 1.1439299583435059, action: buy
# Evaluated Decision at 2019-01-08 18:51:00: predicted 1.1455336809158325, actual 1.1439499855041504, action: buy
# Evaluated Decision at 2019-01-08 18:52:00: predicted 1.145450472831726, actual 1.1439399719238281, action: buy
# Evaluated Decision at 2019-01-08 18:53:00: predicted 1.145334243774414, actual 1.1440099477767944, action: buy
# Evaluated Decision at 2019-01-08 18:54:00: predicted 1.1453710794448853, actual 1.1440199613571167, action: buy
# Evaluated Decision at 2019-01-08 18:55:00: predicted 1.1454905271530151, actual 1.1440199613571167, action: buy
# Evaluated Decision at 2019-01-08 18:56:00: predicted 1.145706057548523, actual 1.144129991531372, action: buy
# Evaluated Decision at 2019-01-08 18:57:00: predicted 1.1457183361053467, actual 1.144129991531372, action: buy
# Evaluated Decision at 2019-01-08 18:58:00: predicted 1.145550012588501, actual 1.1440399885177612, action: sell
# Evaluated Decision at 2019-01-08 18:59:00: predicted 1.145679235458374, actual 1.144110083580017, action: buy
# Evaluated Decision at 2019-01-08 19:00:00: predicted 1.1456315517425537, actual 1.1441199779510498, action: sell
# Evaluated Decision at 2019-01-08 19:02:00: predicted 1.14570951461792, actual 1.1442400217056274, action: buy
# Evaluated Decision at 2019-01-08 19:03:00: predicted 1.145991325378418, actual 1.144279956817627, action: buy
# Evaluated Decision at 2019-01-08 19:04:00: predicted 1.1460739374160767, actual 1.1443400382995605, action: buy
# Evaluated Decision at 2019-01-08 19:05:00: predicted 1.1458818912506104, actual 1.1443300247192383, action: buy
# Evaluated Decision at 2019-01-08 19:06:00: predicted 1.1459215879440308, actual 1.1443800926208496, action: buy
# Evaluated Decision at 2019-01-08 19:07:00: predicted 1.1458542346954346, actual 1.144450068473816, action: buy
# Evaluated Decision at 2019-01-08 19:08:00: predicted 1.1458650827407837, actual 1.144450068473816, action: buy
# Evaluated Decision at 2019-01-08 19:09:00: predicted 1.145801305770874, actual 1.1444900035858154, action: buy
# Evaluated Decision at 2019-01-08 19:10:00: predicted 1.1459581851959229, actual 1.1445300579071045, action: buy
# Evaluated Decision at 2019-01-08 19:11:00: predicted 1.145973563194275, actual 1.1445300579071045, action: buy
# Evaluated Decision at 2019-01-08 19:12:00: predicted 1.1459217071533203, actual 1.1445200443267822, action: buy
# Evaluated Decision at 2019-01-08 19:13:00: predicted 1.1460269689559937, actual 1.1445000171661377, action: buy
# Evaluated Decision at 2019-01-08 19:14:00: predicted 1.1460002660751343, actual 1.144469976425171, action: sell
# Evaluated Decision at 2019-01-08 19:50:00: predicted 1.1456725597381592, actual 1.1450399160385132, action: buy
# Evaluated Decision at 2019-01-08 19:51:00: predicted 1.1457140445709229, actual 1.1450600624084473, action: buy
# Evaluated Decision at 2019-01-08 19:52:00: predicted 1.1455613374710083, actual 1.1452000141143799, action: buy
# Evaluated Decision at 2019-01-08 19:53:00: predicted 1.1455893516540527, actual 1.1452000141143799, action: buy
# Evaluated Decision at 2019-01-08 19:54:00: predicted 1.1455254554748535, actual 1.1453800201416016, action: buy
# Evaluated Decision at 2019-01-08 19:55:00: predicted 1.1456072330474854, actual 1.145799994468689, action: buy
# Evaluated Decision at 2019-01-08 19:56:00: predicted 1.1456884145736694, actual 1.1457099914550781, action: buy
# Evaluated Decision at 2019-01-08 19:57:00: predicted 1.145675539970398, actual 1.145740032196045, action: buy
# Evaluated Decision at 2019-01-08 19:58:00: predicted 1.1455800533294678, actual 1.1455700397491455, action: buy
# Evaluated Decision at 2019-01-08 19:59:00: predicted 1.1455276012420654, actual 1.1457500457763672, action: sell
# Evaluated Decision at 2019-01-08 20:09:00: predicted 1.14567232131958, actual 1.1458200216293335, action: buy
# Evaluated Decision at 2019-01-08 20:10:00: predicted 1.1456241607666016, actual 1.1457799673080444, action: buy
# Evaluated Decision at 2019-01-08 20:11:00: predicted 1.1456537246704102, actual 1.1457600593566895, action: buy
# Evaluated Decision at 2019-01-08 20:12:00: predicted 1.1456981897354126, actual 1.1458100080490112, action: buy
# Evaluated Decision at 2019-01-08 20:13:00: predicted 1.1456950902938843, actual 1.146109938621521, action: buy
# Evaluated Decision at 2019-01-08 20:14:00: predicted 1.145630121231079, actual 1.146220088005066, action: exit
# Evaluated Decision at 2019-01-08 20:21:00: predicted 1.1458030939102173, actual 1.1461700201034546, action: buy
# Evaluated Decision at 2019-01-08 20:22:00: predicted 1.1461440324783325, actual 1.1460800170898438, action: buy
# Evaluated Decision at 2019-01-08 20:23:00: predicted 1.146152138710022, actual 1.1461399793624878, action: buy
# Evaluated Decision at 2019-01-08 20:24:00: predicted 1.1461199522018433, actual 1.1461299657821655, action: buy
# Evaluated Decision at 2019-01-08 20:25:00: predicted 1.1463043689727783, actual 1.1461299657821655, action: buy
# Evaluated Decision at 2019-01-08 20:26:00: predicted 1.146336555480957, actual 1.1460800170898438, action: buy
# Evaluated Decision at 2019-01-08 20:27:00: predicted 1.146203637123108, actual 1.1460200548171997, action: buy
# Evaluated Decision at 2019-01-08 20:28:00: predicted 1.1462621688842773, actual 1.1459500789642334, action: buy
# Evaluated Decision at 2019-01-08 20:29:00: predicted 1.1462161540985107, actual 1.1459200382232666, action: buy
# Evaluated Decision at 2019-01-08 20:30:00: predicted 1.1463960409164429, actual 1.1458100080490112, action: buy
# Evaluated Decision at 2019-01-08 20:31:00: predicted 1.1462366580963135, actual 1.1458200216293335, action: buy
# Evaluated Decision at 2019-01-08 20:32:00: predicted 1.1462652683258057, actual 1.1458200216293335, action: buy
# Evaluated Decision at 2019-01-08 20:33:00: predicted 1.1462376117706299, actual 1.1458200216293335, action: sell
# Evaluated Decision at 2019-01-08 20:34:00: predicted 1.1463018655776978, actual 1.1458100080490112, action: buy
# Evaluated Decision at 2019-01-08 20:35:00: predicted 1.146325945854187, actual 1.1457699537277222, action: buy
# Evaluated Decision at 2019-01-08 20:36:00: predicted 1.146327018737793, actual 1.1458100080490112, action: sell
# Evaluated Decision at 2019-01-08 20:37:00: predicted 1.146469235420227, actual 1.1457099914550781, action: buy
# Evaluated Decision at 2019-01-08 20:38:00: predicted 1.146439790725708, actual 1.1455799341201782, action: buy
# Evaluated Decision at 2019-01-08 20:39:00: predicted 1.1462987661361694, actual 1.1455299854278564, action: exit
# Evaluated Decision at 2019-01-08 21:30:00: predicted 1.1452407836914062, actual 1.1458300352096558, action: buy
# Evaluated Decision at 2019-01-08 21:31:00: predicted 1.1452972888946533, actual 1.1459100246429443, action: buy
# Evaluated Decision at 2019-01-08 21:32:00: predicted 1.145447015762329, actual 1.1462900638580322, action: buy
# Evaluated Decision at 2019-01-08 21:33:00: predicted 1.14540696144104, actual 1.1463099718093872, action: buy
# Evaluated Decision at 2019-01-08 21:34:00: predicted 1.145362377166748, actual 1.1463199853897095, action: buy
# Evaluated Decision at 2019-01-08 21:35:00: predicted 1.145351529121399, actual 1.1464300155639648, action: buy
# Evaluated Decision at 2019-01-08 21:36:00: predicted 1.145398497581482, actual 1.1465799808502197, action: buy
# Evaluated Decision at 2019-01-08 21:37:00: predicted 1.145429253578186, actual 1.146440029144287, action: buy
# Evaluated Decision at 2019-01-08 21:38:00: predicted 1.145442247390747, actual 1.1463799476623535, action: buy
# Evaluated Decision at 2019-01-08 21:39:00: predicted 1.145290732383728, actual 1.1463799476623535, action: buy
# Evaluated Decision at 2019-01-08 21:40:00: predicted 1.1452291011810303, actual 1.1465200185775757, action: sell
# Evaluated Decision at 2019-01-08 21:52:00: predicted 1.1451243162155151, actual 1.146340012550354, action: buy
# Evaluated Decision at 2019-01-08 21:53:00: predicted 1.145237684249878, actual 1.1463099718093872, action: buy
# Evaluated Decision at 2019-01-08 21:54:00: predicted 1.1452512741088867, actual 1.1462299823760986, action: buy
# Evaluated Decision at 2019-01-08 21:55:00: predicted 1.1452362537384033, actual 1.1462100744247437, action: buy
# Evaluated Decision at 2019-01-08 21:56:00: predicted 1.145277738571167, actual 1.1461199522018433, action: buy
# Evaluated Decision at 2019-01-08 21:57:00: predicted 1.1453214883804321, actual 1.1461399793624878, action: buy
# Evaluated Decision at 2019-01-08 21:58:00: predicted 1.1454157829284668, actual 1.146049976348877, action: buy
# Evaluated Decision at 2019-01-08 21:59:00: predicted 1.1455223560333252, actual 1.145990014076233, action: buy
# Evaluated Decision at 2019-01-08 22:00:00: predicted 1.1454776525497437, actual 1.146049976348877, action: buy
# Evaluated Decision at 2019-01-08 22:01:00: predicted 1.1454336643218994, actual 1.1459500789642334, action: buy
# Evaluated Decision at 2019-01-08 22:02:00: predicted 1.1454912424087524, actual 1.1458799839019775, action: buy
# Evaluated Decision at 2019-01-08 22:03:00: predicted 1.1455780267715454, actual 1.145859956741333, action: buy
# Evaluated Decision at 2019-01-08 22:04:00: predicted 1.145532488822937, actual 1.145859956741333, action: buy
# Evaluated Decision at 2019-01-08 22:05:00: predicted 1.1454708576202393, actual 1.1459100246429443, action: buy
# Evaluated Decision at 2019-01-08 22:06:00: predicted 1.145574927330017, actual 1.1459100246429443, action: buy
# Evaluated Decision at 2019-01-08 22:07:00: predicted 1.1456305980682373, actual 1.1459100246429443, action: buy
# Evaluated Decision at 2019-01-08 22:08:00: predicted 1.145736813545227, actual 1.1458100080490112, action: buy
# Evaluated Decision at 2019-01-08 22:09:00: predicted 1.1457961797714233, actual 1.145799994468689, action: buy
# Evaluated Decision at 2019-01-08 22:10:00: predicted 1.1458102464675903, actual 1.1457799673080444, action: buy
# Evaluated Decision at 2019-01-08 22:11:00: predicted 1.145656704902649, actual 1.1457500457763672, action: buy
# Evaluated Decision at 2019-01-08 22:12:00: predicted 1.1457295417785645, actual 1.1456599235534668, action: buy
# Evaluated Decision at 2019-01-08 22:13:00: predicted 1.1457806825637817, actual 1.1455899477005005, action: buy
# Evaluated Decision at 2019-01-08 22:14:00: predicted 1.1456983089447021, actual 1.145550012588501, action: buy
# Evaluated Decision at 2019-01-08 22:15:00: predicted 1.1456114053726196, actual 1.1454499959945679, action: sell
# Evaluated Decision at 2019-01-08 22:16:00: predicted 1.145632266998291, actual 1.1454299688339233, action: buy
# Evaluated Decision at 2019-01-08 22:17:00: predicted 1.1455409526824951, actual 1.145400047302246, action: sell
# Evaluated Decision at 2019-01-08 22:26:00: predicted 1.145716667175293, actual 1.145400047302246, action: buy
# Evaluated Decision at 2019-01-08 22:27:00: predicted 1.1457631587982178, actual 1.1453399658203125, action: buy
# Evaluated Decision at 2019-01-08 22:28:00: predicted 1.1458349227905273, actual 1.1452800035476685, action: buy
# Evaluated Decision at 2019-01-08 22:29:00: predicted 1.1458104848861694, actual 1.1452499628067017, action: buy
# Evaluated Decision at 2019-01-08 22:30:00: predicted 1.1458152532577515, actual 1.145150065422058, action: buy
# Evaluated Decision at 2019-01-08 22:31:00: predicted 1.1458340883255005, actual 1.1452000141143799, action: buy
# Evaluated Decision at 2019-01-08 22:32:00: predicted 1.1458078622817993, actual 1.1452499628067017, action: buy
# Evaluated Decision at 2019-01-08 22:33:00: predicted 1.1456570625305176, actual 1.145300030708313, action: exit
# Evaluated Decision at 2019-01-08 22:34:00: predicted 1.145666241645813, actual 1.1453099250793457, action: buy
# Evaluated Decision at 2019-01-08 22:35:00: predicted 1.14569091796875, actual 1.145359992980957, action: sell
# Evaluated Decision at 2019-01-08 23:13:00: predicted 1.1452611684799194, actual 1.1456999778747559, action: buy
# Evaluated Decision at 2019-01-08 23:14:00: predicted 1.145248532295227, actual 1.1456700563430786, action: sell
# Evaluated Decision at 2019-01-08 23:16:00: predicted 1.1452785730361938, actual 1.1456700563430786, action: buy
# Evaluated Decision at 2019-01-08 23:17:00: predicted 1.145247220993042, actual 1.1457500457763672, action: sell
# Evaluated Decision at 2019-01-08 23:18:00: predicted 1.1452975273132324, actual 1.1458499431610107, action: buy
# Evaluated Decision at 2019-01-08 23:19:00: predicted 1.1452867984771729, actual 1.145900011062622, action: buy
# Evaluated Decision at 2019-01-08 23:20:00: predicted 1.1452913284301758, actual 1.1459400653839111, action: buy
# Evaluated Decision at 2019-01-08 23:21:00: predicted 1.1453551054000854, actual 1.1459100246429443, action: buy
# Evaluated Decision at 2019-01-08 23:22:00: predicted 1.1453639268875122, actual 1.1458700895309448, action: buy
# Evaluated Decision at 2019-01-08 23:23:00: predicted 1.1453765630722046, actual 1.1459100246429443, action: buy
# Evaluated Decision at 2019-01-08 23:24:00: predicted 1.145445466041565, actual 1.1458700895309448, action: buy
# Evaluated Decision at 2019-01-08 23:25:00: predicted 1.1454732418060303, actual 1.1457899808883667, action: buy
# Evaluated Decision at 2019-01-08 23:26:00: predicted 1.145490050315857, actual 1.1457699537277222, action: buy
# Evaluated Decision at 2019-01-08 23:27:00: predicted 1.1454718112945557, actual 1.1457200050354004, action: buy
# Evaluated Decision at 2019-01-08 23:28:00: predicted 1.1454880237579346, actual 1.1456599235534668, action: buy
# Evaluated Decision at 2019-01-08 23:29:00: predicted 1.1454330682754517, actual 1.145609974861145, action: buy
# Evaluated Decision at 2019-01-08 23:30:00: predicted 1.1454412937164307, actual 1.1456000804901123, action: buy
# Evaluated Decision at 2019-01-08 23:31:00: predicted 1.1454960107803345, actual 1.1456700563430786, action: buy
# Evaluated Decision at 2019-01-08 23:32:00: predicted 1.1454904079437256, actual 1.1456899642944336, action: buy
# Evaluated Decision at 2019-01-08 23:33:00: predicted 1.145447850227356, actual 1.1457200050354004, action: sell
# Evaluated Decision at 2019-01-08 23:48:00: predicted 1.1456472873687744, actual 1.1457300186157227, action: buy
# Evaluated Decision at 2019-01-08 23:49:00: predicted 1.1458799839019775, actual 1.145740032196045, action: buy
# Evaluated Decision at 2019-01-08 23:50:00: predicted 1.1460895538330078, actual 1.1457099914550781, action: buy
# Evaluated Decision at 2019-01-08 23:51:00: predicted 1.146104335784912, actual 1.1457099914550781, action: buy
# Evaluated Decision at 2019-01-08 23:52:00: predicted 1.1461541652679443, actual 1.1456700563430786, action: buy
# Evaluated Decision at 2019-01-08 23:53:00: predicted 1.1460696458816528, actual 1.1456599235534668, action: buy
# Evaluated Decision at 2019-01-08 23:54:00: predicted 1.1458797454833984, actual 1.1456599235534668, action: buy
# Evaluated Decision at 2019-01-08 23:55:00: predicted 1.145978569984436, actual 1.1456300020217896, action: buy
# Evaluated Decision at 2019-01-08 23:56:00: predicted 1.1459145545959473, actual 1.145740032196045, action: buy
# Evaluated Decision at 2019-01-08 23:57:00: predicted 1.1459840536117554, actual 1.1457500457763672, action: buy
# Evaluated Decision at 2019-01-08 23:58:00: predicted 1.145932674407959, actual 1.1457600593566895, action: buy
# Evaluated Decision at 2019-01-08 23:59:00: predicted 1.145878791809082, actual 1.1456300020217896, action: buy
# Evaluated Decision at 2019-01-09 00:00:00: predicted 1.1459345817565918, actual 1.1455299854278564, action: sell
# Evaluated Decision at 2019-01-09 00:32:00: predicted 1.1457834243774414, actual 1.1454700231552124, action: buy
# Evaluated Decision at 2019-01-09 00:33:00: predicted 1.145772099494934, actual 1.1454700231552124, action: sell
# Evaluated Decision at 2019-01-09 00:35:00: predicted 1.1457223892211914, actual 1.1455899477005005, action: buy
# Evaluated Decision at 2019-01-09 00:36:00: predicted 1.145768165588379, actual 1.1456300020217896, action: buy
# Evaluated Decision at 2019-01-09 00:37:00: predicted 1.1457476615905762, actual 1.1455899477005005, action: buy
# Evaluated Decision at 2019-01-09 00:38:00: predicted 1.1461052894592285, actual 1.1456199884414673, action: buy
# Evaluated Decision at 2019-01-09 00:39:00: predicted 1.1461067199707031, actual 1.145609974861145, action: buy
# Evaluated Decision at 2019-01-09 00:40:00: predicted 1.146161675453186, actual 1.1455799341201782, action: buy
# Evaluated Decision at 2019-01-09 00:41:00: predicted 1.1460951566696167, actual 1.1455899477005005, action: buy
# Evaluated Decision at 2019-01-09 00:42:00: predicted 1.1460767984390259, actual 1.1456000804901123, action: buy
# Evaluated Decision at 2019-01-09 00:43:00: predicted 1.145944356918335, actual 1.1455899477005005, action: buy
# Evaluated Decision at 2019-01-09 00:44:00: predicted 1.1458796262741089, actual 1.1455700397491455, action: buy
# Evaluated Decision at 2019-01-09 00:45:00: predicted 1.1458966732025146, actual 1.1455600261688232, action: buy
# Evaluated Decision at 2019-01-09 00:46:00: predicted 1.1459230184555054, actual 1.145550012588501, action: buy
# Evaluated Decision at 2019-01-09 00:47:00: predicted 1.1458871364593506, actual 1.1454800367355347, action: buy
# Evaluated Decision at 2019-01-09 00:48:00: predicted 1.145930528640747, actual 1.1455600261688232, action: buy
# Evaluated Decision at 2019-01-09 00:49:00: predicted 1.1459710597991943, actual 1.1455700397491455, action: sell
# Evaluated Decision at 2019-01-09 01:05:00: predicted 1.1456717252731323, actual 1.1460800170898438, action: buy
# Evaluated Decision at 2019-01-09 01:06:00: predicted 1.1457000970840454, actual 1.1460800170898438, action: buy
# Evaluated Decision at 2019-01-09 01:07:00: predicted 1.1456897258758545, actual 1.1461199522018433, action: buy
# Evaluated Decision at 2019-01-09 01:08:00: predicted 1.1456830501556396, actual 1.1460599899291992, action: buy
# Evaluated Decision at 2019-01-09 01:09:00: predicted 1.1456599235534668, actual 1.1460700035095215, action: sell
# Evaluated Decision at 2019-01-09 01:15:00: predicted 1.1456670761108398, actual 1.1459200382232666, action: buy
# Evaluated Decision at 2019-01-09 01:16:00: predicted 1.1459485292434692, actual 1.1458799839019775, action: buy
# Evaluated Decision at 2019-01-09 01:17:00: predicted 1.1461939811706543, actual 1.1458799839019775, action: buy
# Evaluated Decision at 2019-01-09 01:18:00: predicted 1.146289348602295, actual 1.1459200382232666, action: buy
# Evaluated Decision at 2019-01-09 01:19:00: predicted 1.1461957693099976, actual 1.1459500789642334, action: buy
# Evaluated Decision at 2019-01-09 01:20:00: predicted 1.1461870670318604, actual 1.1459400653839111, action: buy
# Evaluated Decision at 2019-01-09 01:21:00: predicted 1.145934820175171, actual 1.1458499431610107, action: buy
# Evaluated Decision at 2019-01-09 01:22:00: predicted 1.1458640098571777, actual 1.1459200382232666, action: buy
# Evaluated Decision at 2019-01-09 01:23:00: predicted 1.145812749862671, actual 1.1458899974822998, action: buy
# Evaluated Decision at 2019-01-09 01:24:00: predicted 1.146018147468567, actual 1.1458700895309448, action: buy
# Evaluated Decision at 2019-01-09 01:25:00: predicted 1.145839810371399, actual 1.1458700895309448, action: buy
# Evaluated Decision at 2019-01-09 01:26:00: predicted 1.1456810235977173, actual 1.1458499431610107, action: sell
# Evaluated Decision at 2019-01-09 01:34:00: predicted 1.1459071636199951, actual 1.1457600593566895, action: buy
# Evaluated Decision at 2019-01-09 01:35:00: predicted 1.1459550857543945, actual 1.1457200050354004, action: sell
# Evaluated Decision at 2019-01-09 01:36:00: predicted 1.146004319190979, actual 1.1457200050354004, action: buy
# Evaluated Decision at 2019-01-09 01:37:00: predicted 1.1459466218948364, actual 1.1457699537277222, action: buy
# Evaluated Decision at 2019-01-09 01:38:00: predicted 1.1458691358566284, actual 1.1457699537277222, action: buy
# Evaluated Decision at 2019-01-09 01:39:00: predicted 1.1458534002304077, actual 1.1457899808883667, action: buy
# Evaluated Decision at 2019-01-09 01:40:00: predicted 1.145805835723877, actual 1.1458200216293335, action: buy
# Evaluated Decision at 2019-01-09 01:41:00: predicted 1.1458344459533691, actual 1.145900011062622, action: buy
# Evaluated Decision at 2019-01-09 01:42:00: predicted 1.145858645439148, actual 1.1458899974822998, action: exit
# Evaluated Decision at 2019-01-09 01:56:00: predicted 1.1462262868881226, actual 1.146030068397522, action: buy
# Evaluated Decision at 2019-01-09 01:57:00: predicted 1.1459816694259644, actual 1.1460100412368774, action: buy
# Evaluated Decision at 2019-01-09 01:58:00: predicted 1.1458532810211182, actual 1.146049976348877, action: exit
# Evaluated Decision at 2019-01-09 01:59:00: predicted 1.1460480690002441, actual 1.1460700035095215, action: buy
# Evaluated Decision at 2019-01-09 02:00:00: predicted 1.1457610130310059, actual 1.146090030670166, action: exit
# Evaluated Decision at 2019-01-09 02:02:00: predicted 1.1460680961608887, actual 1.145799994468689, action: buy
# Evaluated Decision at 2019-01-09 02:03:00: predicted 1.145971417427063, actual 1.1457500457763672, action: buy
# Evaluated Decision at 2019-01-09 02:04:00: predicted 1.1462608575820923, actual 1.1457300186157227, action: buy
# Evaluated Decision at 2019-01-09 02:05:00: predicted 1.1463570594787598, actual 1.1456599235534668, action: buy
# Evaluated Decision at 2019-01-09 02:06:00: predicted 1.146096110343933, actual 1.1456199884414673, action: buy
# Evaluated Decision at 2019-01-09 02:07:00: predicted 1.1461713314056396, actual 1.1456800699234009, action: sell
# Evaluated Decision at 2019-01-09 02:08:00: predicted 1.1461809873580933, actual 1.1459599733352661, action: buy
# Evaluated Decision at 2019-01-09 02:09:00: predicted 1.1462986469268799, actual 1.1458200216293335, action: buy
# Evaluated Decision at 2019-01-09 02:10:00: predicted 1.146181583404541, actual 1.1458100080490112, action: buy
# Evaluated Decision at 2019-01-09 02:11:00: predicted 1.1461306810379028, actual 1.1458200216293335, action: buy
# Evaluated Decision at 2019-01-09 02:12:00: predicted 1.146227478981018, actual 1.1458100080490112, action: buy
# Evaluated Decision at 2019-01-09 02:13:00: predicted 1.1461070775985718, actual 1.1457200050354004, action: sell
# Evaluated Decision at 2019-01-09 02:14:00: predicted 1.146127462387085, actual 1.1456700563430786, action: buy
# Evaluated Decision at 2019-01-09 02:15:00: predicted 1.146364688873291, actual 1.1457899808883667, action: sell
# Evaluated Decision at 2019-01-09 02:17:00: predicted 1.146448016166687, actual 1.1458200216293335, action: buy
# Evaluated Decision at 2019-01-09 02:18:00: predicted 1.1465944051742554, actual 1.1457899808883667, action: buy
# Evaluated Decision at 2019-01-09 02:19:00: predicted 1.1465176343917847, actual 1.1457899808883667, action: buy
# ...
# Evaluated Decision at 2019-01-09 08:55:00: predicted 1.1469188928604126, actual 1.1452100276947021, action: buy
# Evaluated Decision at 2019-01-09 08:56:00: predicted 1.1471641063690186, actual 1.1449699401855469, action: buy
# Evaluated Decision at 2019-01-09 08:57:00: predicted 1.1471019983291626, actual 1.1449699401855469, action: buy
# Evaluated Decision at 2019-01-09 08:58:00: predicted 1.1472597122192383, actual 1.1450799703598022, action: buy
# Evaluated Decision at 2019-01-09 08:59:00: predicted 1.1472891569137573, actual 1.1451199054718018, action: buy
# Evaluated Decision at 2019-01-09 09:00:00: predicted 1.1471925973892212, actual 1.1451199054718018, action: buy
# Evaluated Decision at 2019-01-09 09:01:00: predicted 1.147116780281067, actual 1.1449799537658691, action: buy
# Evaluated Decision at 2019-01-09 09:02:00: predicted 1.147035837173462, actual 1.144990086555481, action: buy
# Evaluated Decision at 2019-01-09 09:03:00: predicted 1.1468157768249512, actual 1.144990086555481, action: sell
# Evaluated Decision at 2019-01-09 09:04:00: predicted 1.146892786026001, actual 1.1452299356460571, action: buy
# Evaluated Decision at 2019-01-09 09:05:00: predicted 1.1468743085861206, actual 1.1452600955963135, action: sell
# Evaluated Decision at 2019-01-09 09:06:00: predicted 1.1471140384674072, actual 1.1453700065612793, action: buy
# Evaluated Decision at 2019-01-09 09:07:00: predicted 1.1467399597167969, actual 1.1454299688339233, action: sell
# Evaluated Decision at 2019-01-09 09:14:00: predicted 1.1470592021942139, actual 1.145650029182434, action: buy
# Evaluated Decision at 2019-01-09 09:15:00: predicted 1.1470822095870972, actual 1.1454700231552124, action: buy
# Evaluated Decision at 2019-01-09 09:16:00: predicted 1.1468478441238403, actual 1.1455700397491455, action: sell
# Evaluated Decision at 2019-01-09 09:20:00: predicted 1.1470035314559937, actual 1.1455399990081787, action: buy
# Evaluated Decision at 2019-01-09 09:21:00: predicted 1.1473438739776611, actual 1.1454600095748901, action: buy
# Evaluated Decision at 2019-01-09 09:22:00: predicted 1.1474189758300781, actual 1.1454100608825684, action: buy
# Evaluated Decision at 2019-01-09 09:23:00: predicted 1.1472376585006714, actual 1.1454100608825684, action: buy
# Evaluated Decision at 2019-01-09 09:24:00: predicted 1.147923469543457, actual 1.1452000141143799, action: buy
# Evaluated Decision at 2019-01-09 09:25:00: predicted 1.1492691040039062, actual 1.1452699899673462, action: buy
# Evaluated Decision at 2019-01-09 09:26:00: predicted 1.1502403020858765, actual 1.1453700065612793, action: buy
# Evaluated Decision at 2019-01-09 09:27:00: predicted 1.1510783433914185, actual 1.1452100276947021, action: buy
# Evaluated Decision at 2019-01-09 09:28:00: predicted 1.1501610279083252, actual 1.1452200412750244, action: buy
# Evaluated Decision at 2019-01-09 09:29:00: predicted 1.1505142450332642, actual 1.1452699899673462, action: buy
# Evaluated Decision at 2019-01-09 09:30:00: predicted 1.150970697402954, actual 1.145169973373413, action: buy
# Evaluated Decision at 2019-01-09 09:31:00: predicted 1.1512763500213623, actual 1.1450399160385132, action: buy
# Evaluated Decision at 2019-01-09 09:32:00: predicted 1.1511479616165161, actual 1.1453300714492798, action: buy
# Evaluated Decision at 2019-01-09 09:33:00: predicted 1.1513394117355347, actual 1.1455899477005005, action: buy
# Evaluated Decision at 2019-01-09 09:34:00: predicted 1.1508134603500366, actual 1.1455799341201782, action: buy
# Evaluated Decision at 2019-01-09 09:35:00: predicted 1.151425838470459, actual 1.145740032196045, action: buy
# Evaluated Decision at 2019-01-09 09:36:00: predicted 1.1515682935714722, actual 1.1461800336837769, action: buy
# Evaluated Decision at 2019-01-09 09:37:00: predicted 1.1515498161315918, actual 1.146090030670166, action: buy
# Evaluated Decision at 2019-01-09 09:38:00: predicted 1.1515599489212036, actual 1.1459500789642334, action: buy
# Evaluated Decision at 2019-01-09 09:39:00: predicted 1.1511437892913818, actual 1.146030068397522, action: buy
# Evaluated Decision at 2019-01-09 09:40:00: predicted 1.1516045331954956, actual 1.1460700035095215, action: buy
# Evaluated Decision at 2019-01-09 09:41:00: predicted 1.1515932083129883, actual 1.1459800004959106, action: buy
# Evaluated Decision at 2019-01-09 09:42:00: predicted 1.1513757705688477, actual 1.1459200382232666, action: sell
# Evaluated Decision at 2019-01-09 09:43:00: predicted 1.1513742208480835, actual 1.1459699869155884, action: buy
# Evaluated Decision at 2019-01-09 09:44:00: predicted 1.151526927947998, actual 1.1463299989700317, action: buy
# Evaluated Decision at 2019-01-09 09:45:00: predicted 1.1518617868423462, actual 1.1463700532913208, action: buy
# Evaluated Decision at 2019-01-09 09:46:00: predicted 1.1521403789520264, actual 1.1463600397109985, action: buy
# Evaluated Decision at 2019-01-09 09:47:00: predicted 1.1519745588302612, actual 1.1464200019836426, action: buy
# Evaluated Decision at 2019-01-09 09:48:00: predicted 1.1515281200408936, actual 1.1463199853897095, action: sell
# Evaluated Decision at 2019-01-09 09:49:00: predicted 1.1520445346832275, actual 1.146340012550354, action: buy
# Evaluated Decision at 2019-01-09 09:50:00: predicted 1.1521005630493164, actual 1.146440029144287, action: buy
# Evaluated Decision at 2019-01-09 09:51:00: predicted 1.15230393409729, actual 1.14628005027771, action: buy
# Evaluated Decision at 2019-01-09 09:52:00: predicted 1.1525136232376099, actual 1.146109938621521, action: buy
# Evaluated Decision at 2019-01-09 09:53:00: predicted 1.1523125171661377, actual 1.146090030670166, action: buy
# Evaluated Decision at 2019-01-09 09:54:00: predicted 1.1523878574371338, actual 1.1461700201034546, action: buy
# Evaluated Decision at 2019-01-09 09:55:00: predicted 1.1521703004837036, actual 1.1463600397109985, action: buy
# Evaluated Decision at 2019-01-09 09:56:00: predicted 1.152494192123413, actual 1.146299958229065, action: buy
# Evaluated Decision at 2019-01-09 09:57:00: predicted 1.1525617837905884, actual 1.1462299823760986, action: buy
# Evaluated Decision at 2019-01-09 09:58:00: predicted 1.1523357629776, actual 1.1459200382232666, action: sell
# Evaluated Decision at 2019-01-09 09:59:00: predicted 1.1525133848190308, actual 1.1463199853897095, action: buy
# Evaluated Decision at 2019-01-09 10:00:00: predicted 1.1524940729141235, actual 1.1465500593185425, action: buy
# Evaluated Decision at 2019-01-09 10:01:00: predicted 1.1526564359664917, actual 1.1465699672698975, action: buy
# Evaluated Decision at 2019-01-09 10:02:00: predicted 1.1527642011642456, actual 1.1468900442123413, action: buy
# Evaluated Decision at 2019-01-09 10:03:00: predicted 1.153222918510437, actual 1.1469500064849854, action: buy
# Evaluated Decision at 2019-01-09 10:04:00: predicted 1.1532797813415527, actual 1.1469800472259521, action: buy
# Evaluated Decision at 2019-01-09 10:05:00: predicted 1.153182029724121, actual 1.1471099853515625, action: buy
# Evaluated Decision at 2019-01-09 10:06:00: predicted 1.1531704664230347, actual 1.147339940071106, action: buy
# Evaluated Decision at 2019-01-09 10:07:00: predicted 1.152974009513855, actual 1.147279977798462, action: buy
# Evaluated Decision at 2019-01-09 10:08:00: predicted 1.1530206203460693, actual 1.1473900079727173, action: buy
# Evaluated Decision at 2019-01-09 10:09:00: predicted 1.1534051895141602, actual 1.14752995967865, action: buy
# Evaluated Decision at 2019-01-09 10:10:00: predicted 1.1533230543136597, actual 1.1474699974060059, action: buy
# Evaluated Decision at 2019-01-09 10:11:00: predicted 1.1532583236694336, actual 1.1474699974060059, action: buy
# Evaluated Decision at 2019-01-09 10:12:00: predicted 1.1533021926879883, actual 1.1472100019454956, action: buy
# Evaluated Decision at 2019-01-09 10:13:00: predicted 1.1530410051345825, actual 1.1471199989318848, action: sell
# Evaluated Decision at 2019-01-09 10:54:00: predicted 1.1512244939804077, actual 1.1518999338150024, action: buy
# Evaluated Decision at 2019-01-09 10:55:00: predicted 1.1512607336044312, actual 1.1523699760437012, action: sell
# Evaluated Decision at 2019-01-09 10:56:00: predicted 1.1515228748321533, actual 1.1525700092315674, action: buy
# Evaluated Decision at 2019-01-09 10:57:00: predicted 1.1514579057693481, actual 1.152500033378601, action: buy
# Evaluated Decision at 2019-01-09 10:58:00: predicted 1.1514047384262085, actual 1.152519941329956, action: buy
# Evaluated Decision at 2019-01-09 10:59:00: predicted 1.1515675783157349, actual 1.1525400876998901, action: buy
# Evaluated Decision at 2019-01-09 11:00:00: predicted 1.151374101638794, actual 1.1527099609375, action: buy
# Evaluated Decision at 2019-01-09 11:01:00: predicted 1.1513357162475586, actual 1.1532599925994873, action: sell
# Evaluated Decision at 2019-01-09 11:02:00: predicted 1.1514003276824951, actual 1.153059959411621, action: buy
# Evaluated Decision at 2019-01-09 11:03:00: predicted 1.151440143585205, actual 1.1531100273132324, action: sell
# Evaluated Decision at 2019-01-09 11:13:00: predicted 1.1518023014068604, actual 1.1538000106811523, action: buy
# Evaluated Decision at 2019-01-09 11:14:00: predicted 1.1521369218826294, actual 1.1539900302886963, action: buy
# Evaluated Decision at 2019-01-09 11:15:00: predicted 1.1519043445587158, actual 1.1539900302886963, action: buy
# Evaluated Decision at 2019-01-09 11:16:00: predicted 1.1520189046859741, actual 1.1537799835205078, action: buy
# Evaluated Decision at 2019-01-09 11:17:00: predicted 1.1519262790679932, actual 1.15378999710083, action: buy
# Evaluated Decision at 2019-01-09 11:18:00: predicted 1.1518325805664062, actual 1.1535499095916748, action: buy
# Evaluated Decision at 2019-01-09 11:19:00: predicted 1.1517943143844604, actual 1.1540199518203735, action: buy
# Evaluated Decision at 2019-01-09 11:20:00: predicted 1.1520906686782837, actual 1.1540600061416626, action: buy
# Evaluated Decision at 2019-01-09 11:21:00: predicted 1.1521129608154297, actual 1.1539599895477295, action: buy
# Evaluated Decision at 2019-01-09 11:22:00: predicted 1.1520326137542725, actual 1.1539100408554077, action: buy
# Evaluated Decision at 2019-01-09 11:23:00: predicted 1.152011513710022, actual 1.153880000114441, action: buy
# Evaluated Decision at 2019-01-09 11:24:00: predicted 1.1520956754684448, actual 1.1536999940872192, action: sell
# Evaluated Decision at 2019-01-09 11:26:00: predicted 1.152439832687378, actual 1.1533899307250977, action: buy
# Evaluated Decision at 2019-01-09 11:27:00: predicted 1.1524953842163086, actual 1.15323007106781, action: buy
# Evaluated Decision at 2019-01-09 11:28:00: predicted 1.1525672674179077, actual 1.1531200408935547, action: buy
# Evaluated Decision at 2019-01-09 11:29:00: predicted 1.1525931358337402, actual 1.1531399488449097, action: buy
# Evaluated Decision at 2019-01-09 11:30:00: predicted 1.1523653268814087, actual 1.1531200408935547, action: buy
# Evaluated Decision at 2019-01-09 11:31:00: predicted 1.152695655822754, actual 1.1531100273132324, action: buy
# Evaluated Decision at 2019-01-09 11:32:00: predicted 1.1530780792236328, actual 1.1528899669647217, action: buy
# Evaluated Decision at 2019-01-09 11:33:00: predicted 1.1531014442443848, actual 1.152690052986145, action: buy
# Evaluated Decision at 2019-01-09 11:34:00: predicted 1.153071641921997, actual 1.1527299880981445, action: buy
# Evaluated Decision at 2019-01-09 11:35:00: predicted 1.1528509855270386, actual 1.1526199579238892, action: buy
# Evaluated Decision at 2019-01-09 11:36:00: predicted 1.1528633832931519, actual 1.1524900197982788, action: buy
# Evaluated Decision at 2019-01-09 11:37:00: predicted 1.1528946161270142, actual 1.1525800228118896, action: buy
# Evaluated Decision at 2019-01-09 11:38:00: predicted 1.1528551578521729, actual 1.152500033378601, action: sell
# Evaluated Decision at 2019-01-09 12:04:00: predicted 1.1522681713104248, actual 1.1517000198364258, action: buy
# Evaluated Decision at 2019-01-09 12:05:00: predicted 1.1521506309509277, actual 1.1517200469970703, action: sell
# Evaluated Decision at 2019-01-09 12:19:00: predicted 1.1527111530303955, actual 1.1516799926757812, action: buy
# Evaluated Decision at 2019-01-09 12:20:00: predicted 1.152527928352356, actual 1.151669979095459, action: buy
# Evaluated Decision at 2019-01-09 12:21:00: predicted 1.1524088382720947, actual 1.1515599489212036, action: buy
# Evaluated Decision at 2019-01-09 12:22:00: predicted 1.1525710821151733, actual 1.151650071144104, action: buy
# Evaluated Decision at 2019-01-09 12:23:00: predicted 1.1525356769561768, actual 1.152209997177124, action: sell
# Evaluated Decision at 2019-01-09 12:25:00: predicted 1.1526252031326294, actual 1.1526700258255005, action: buy
# Evaluated Decision at 2019-01-09 12:26:00: predicted 1.1524484157562256, actual 1.1526000499725342, action: sell
# Evaluated Decision at 2019-01-09 12:28:00: predicted 1.1527526378631592, actual 1.1524399518966675, action: buy
# Evaluated Decision at 2019-01-09 12:29:00: predicted 1.1526858806610107, actual 1.1522799730300903, action: sell
# Evaluated Decision at 2019-01-09 12:50:00: predicted 1.1530799865722656, actual 1.1531800031661987, action: buy
# Evaluated Decision at 2019-01-09 12:51:00: predicted 1.1530194282531738, actual 1.1530699729919434, action: buy
# Evaluated Decision at 2019-01-09 12:52:00: predicted 1.1527750492095947, actual 1.1529699563980103, action: exit
# Evaluated Decision at 2019-01-09 13:26:00: predicted 1.153085470199585, actual 1.1527600288391113, action: buy
# Evaluated Decision at 2019-01-09 13:27:00: predicted 1.1531251668930054, actual 1.1527299880981445, action: buy
# Evaluated Decision at 2019-01-09 13:28:00: predicted 1.153151273727417, actual 1.1527799367904663, action: buy
# Evaluated Decision at 2019-01-09 13:29:00: predicted 1.1531407833099365, actual 1.1531599760055542, action: sell
# 2024-10-31 10:44:05,396 - DEBUG - Data index start: 2019-01-02 00:30:00, end: 2019-01-09 13:54:00
# 2024-10-31 10:44:05,396 - DEBUG - Length of self.portfolio_series: 1587
# 2024-10-31 10:44:05,397 - DEBUG - First few entries of self.portfolio_series:
# 2019-01-08 11:24:00    100000.0000
# 2019-01-08 11:25:00    100000.0000
# 2019-01-08 11:26:00    100000.0000
# 2019-01-08 11:27:00    100000.0000
# 2019-01-08 11:28:00    100002.1845
# Freq: min, dtype: float64
# 2024-10-31 10:44:05,398 - INFO - Total Number of Trading Days: 2
# 2024-10-31 10:44:05,398 - INFO - Average Trading Minutes Per Day: 793.50
# 2024-10-31 10:44:05,398 - DEBUG - Date: 2019-01-08, Minutes: 756
# 2024-10-31 10:44:05,398 - DEBUG - Date: 2019-01-09, Minutes: 831
# 2024-10-31 10:44:05,398 - DEBUG - Hit Ratio: 80.8695652173913
# 2024-10-31 10:44:05,399 - DEBUG - Strategy Gain: 1.3630268499998492
# 2024-10-31 10:44:05,399 - DEBUG - Maximum Drawdown: -0.000571156743662149
# 2024-10-31 10:44:05,399 - DEBUG - Expected Portfolio Return (Rx): 8.537648232618345e-06
# 2024-10-31 10:44:05,399 - DEBUG - Standard Deviation of Portfolio Return (StdDev Rx): 5.549880452576959e-05
# 2024-10-31 10:44:05,399 - DEBUG - Risk-Free Rate (Rf): 0.01, Sharpe Ratio: -180.0302265452957
# 2024-10-31 10:44:05,400 - DEBUG - Average Return (Rp): 8.537648232618345e-06
# 2024-10-31 10:44:05,400 - DEBUG - Target Rate of Return (T): 0.0001
# 2024-10-31 10:44:05,400 - DEBUG - Downside Deviation (Dd): 0.00010228097204899871
# 2024-10-31 10:44:05,400 - DEBUG - Sortino Ratio: -0.8942264620203817
# Confusion Matrix:
# [[338  38]
#  [300  54]]
# 2019-01-08 11:24:00    100000.00000
# 2019-01-08 11:25:00    100000.00000
# 2019-01-08 11:26:00    100000.00000
# 2019-01-08 11:27:00    100000.00000
# 2019-01-08 11:28:00    100002.18450
#                            ...
# 2019-01-09 13:46:00    101363.02685
# 2019-01-09 13:47:00    101363.02685
# 2019-01-09 13:48:00    101363.02685
# 2019-01-09 13:49:00    101363.02685
# 2019-01-09 13:50:00    101363.02685
# Freq: min, Length: 1587, dtype: float64
# Final portfolio value: $101363.03
# Hit Ratio: 80.87%
# Strategy Gain: 1.36%
# Maximum Drawdown: -0.0571%
# Sharpe Ratio: -180.03
# Sortino Ratio: -0.89
# Final Trading Strategy Value: 101363.02684999985
# Final Buy and Hold Value: 1.5089538445237927
# Absolute Difference: 101361.51789615533
