# %%
import yfinance as yf
import pandas as pd
import numpy as np
import torch
import torch.nn as nn
import torch.optim as optim
from sklearn.preprocessing import MinMaxScaler
import matplotlib.pyplot as plt
import ffn
import os
from frouros.detectors.concept_drift import DDM, DDMConfig
from frouros.metrics import PrequentialError


# 1. Data Preparation

# Load data
ticker = 'AAPL'
data = pd.read_csv('../../datasets/FIXED_EODHD_EURUSD_HISTORICAL_2019_2024_1min.csv').head(4000)

# Prepare features and target
data['Next_High'] = data['high'].shift(-1)  # Target variable: next period's high
data['Return'] = data['close'].pct_change()  # Price returns
data['Volatility'] = data['Return'].rolling(window=5).std()  # 5-period rolling volatility
data['High_Low_Range'] = (data['high'] - data['low']) / data['low']  # Intraday high-low range
data['Prev_Close_Rel_High'] = (data['close'].shift(1) - data['high']) / data['high']  # Previous close relative to high
data.dropna(inplace=True)

# Normalize the features
feature_scaler = MinMaxScaler(feature_range=(0, 1))
scaled_features = feature_scaler.fit_transform(data[['open', 'high', 'low', 'close', 'volume', 'Return', 'Volatility', 'High_Low_Range', 'Prev_Close_Rel_High']])

# Normalize the target
target_scaler = MinMaxScaler(feature_range=(0, 1))
scaled_target = target_scaler.fit_transform(data[['Next_High']])

# Create dataset function for LSTM
def create_dataset(features, target, time_step=1):
    X, y = [], []
    for i in range(len(features) - time_step - 1):
        X.append(features[i:(i + time_step), :])
        y.append(target[i + time_step])
    return np.array(X), np.array(y)

# Define time step for LSTM model
time_step = 60
X, y = create_dataset(scaled_features, scaled_target, time_step)

# Reshape data to fit PyTorch LSTM input: (samples, time_step, features)
X = X.reshape(X.shape[0], X.shape[1], X.shape[2])

# Split data into training, validation, and testing sets
train_size = int(len(X) * 0.8)
val_size = int(len(X) * 0.1)  # 10% for validation
X_train, X_val, X_test = X[:train_size], X[train_size:train_size + val_size], X[train_size + val_size:]
y_train, y_val, y_test = y[:train_size], y[train_size:train_size + val_size], y[train_size + val_size:]

# Convert data to PyTorch tensors
X_train = torch.tensor(X_train, dtype=torch.float32)
y_train = torch.tensor(y_train, dtype=torch.float32)
X_val = torch.tensor(X_val, dtype=torch.float32)
y_val = torch.tensor(y_val, dtype=torch.float32)
X_test = torch.tensor(X_test, dtype=torch.float32)
y_test = torch.tensor(y_test, dtype=torch.float32)

# Check if GPU is available
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(f'Using device: {device}')

# Move tensors to the GPU if available
X_train, y_train = X_train.to(device), y_train.to(device)
X_val, y_val = X_val.to(device), y_val.to(device)
X_test, y_test = X_test.to(device), y_test.to(device)

# 2. Build and Train the LSTM Model

class LSTMModel(nn.Module):
    def __init__(self, input_size, hidden_size, output_size, num_layers=2):
        super(LSTMModel, self).__init__()
        self.hidden_size = hidden_size
        self.num_layers = num_layers
        self.lstm = nn.LSTM(input_size, hidden_size, num_layers, batch_first=True)
        self.fc = nn.Linear(hidden_size, output_size)

    def forward(self, x):
        h0 = torch.zeros(self.num_layers, x.size(0), self.hidden_size).to(device)
        c0 = torch.zeros(self.num_layers, x.size(0), self.hidden_size).to(device)
        
        out, _ = self.lstm(x, (h0, c0))  # LSTM output
        out = self.fc(out[:, -1, :])  # Take the output of the last time step
        return out

# Hyperparameters
input_size = X_train.shape[2]  # Number of features
hidden_size = 100
output_size = 1
num_layers = 2
num_epochs = 100
batch_size = 16
learning_rate = 0.01
patience = 8  # Early stopping patience

# Create LSTM model
model = LSTMModel(input_size, hidden_size, output_size, num_layers).to(device)

# Loss and optimizer
criterion = nn.MSELoss()
optimizer = optim.Adam(model.parameters(), lr=learning_rate)

# DataLoader for batching
train_loader = torch.utils.data.DataLoader(dataset=list(zip(X_train, y_train)), batch_size=batch_size, shuffle=True)

# Lists to store the loss values for plotting
train_losses = []
val_losses = []

# Early stopping variables
best_val_loss = float('inf')
epochs_without_improvement = 0

# Train the model
for epoch in range(num_epochs):
    model.train()
    epoch_loss = 0
    for i, (features, labels) in enumerate(train_loader):
        # Forward pass
        outputs = model(features)
        loss = criterion(outputs, labels)
        
        # Backward pass and optimization
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()

        # Accumulate the loss for each batch
        epoch_loss += loss.item()

    # Average loss for the epoch
    avg_epoch_loss = epoch_loss / len(train_loader)
    train_losses.append(avg_epoch_loss)

    # Validation phase
    model.eval()
    with torch.no_grad():
        val_outputs = model(X_val)
        val_loss = criterion(val_outputs, y_val).item()
        val_losses.append(val_loss)

    # Print the progress
    print(f'Epoch [{epoch+1}/{num_epochs}], Loss: {avg_epoch_loss:.6f}, Val Loss: {val_loss:.6f}')

    # Early stopping check
    if val_loss < best_val_loss:
        best_val_loss = val_loss
        epochs_without_improvement = 0
        
        # Save the model
        torch.save(model.state_dict(), 'lstm_model.pth')
        print("Model saved.")
    else:
        epochs_without_improvement += 1
        if epochs_without_improvement >= patience:
            print(f'Early stopping triggered after {epoch + 1} epochs without improvement.')
            break


# 3. Model Evaluation
model.eval()  # Set model to evaluation mode

# Make predictions
with torch.no_grad():
    predictions = model(X_test)
    predictions = predictions.cpu().numpy()
    y_test = y_test.cpu().numpy()

# Inverse transform predictions and actual values to original scale
predictions = target_scaler.inverse_transform(predictions)
y_test = target_scaler.inverse_transform(y_test)

# 4. Plot results
plt.figure(figsize=(12, 6))
plt.plot(train_losses, label='Training Loss')
plt.plot(val_losses, label='Validation Loss')
plt.title('Model Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.show()

# Plot actual vs predicted values
plt.figure(figsize=(12, 6))
plt.plot(y_test, label='Actual')
plt.plot(predictions, label='Predicted')
plt.title('Actual vs Predicted')
plt.xlabel('Time')
plt.ylabel('Next High Price')
plt.legend()
plt.show()
# Out:
# Using device: cuda
# Epoch [1/100], Loss: 0.036017, Val Loss: 0.000499
# Model saved.
# Epoch [2/100], Loss: 0.000263, Val Loss: 0.000614
# Epoch [3/100], Loss: 0.000290, Val Loss: 0.000371
# Model saved.
# Epoch [4/100], Loss: 0.000394, Val Loss: 0.000450
# Epoch [5/100], Loss: 0.000235, Val Loss: 0.000329
# Model saved.
# Epoch [6/100], Loss: 0.000220, Val Loss: 0.000351
# Epoch [7/100], Loss: 0.000236, Val Loss: 0.000352
# Epoch [8/100], Loss: 0.000246, Val Loss: 0.000315
# Model saved.
# Epoch [9/100], Loss: 0.000290, Val Loss: 0.000425
# Epoch [10/100], Loss: 0.000257, Val Loss: 0.000404
# Epoch [11/100], Loss: 0.000306, Val Loss: 0.000351
# Epoch [12/100], Loss: 0.000245, Val Loss: 0.000352
# Epoch [13/100], Loss: 0.000267, Val Loss: 0.000430
# Epoch [14/100], Loss: 0.000257, Val Loss: 0.000617
# Epoch [15/100], Loss: 0.000315, Val Loss: 0.000312
# Model saved.
# Epoch [16/100], Loss: 0.000229, Val Loss: 0.000314
# Epoch [17/100], Loss: 0.000242, Val Loss: 0.000374
# Epoch [18/100], Loss: 0.000207, Val Loss: 0.000333
# Epoch [19/100], Loss: 0.000229, Val Loss: 0.000333
# Epoch [20/100], Loss: 0.000208, Val Loss: 0.000431
# Epoch [21/100], Loss: 0.000222, Val Loss: 0.000305
# Model saved.
# Epoch [22/100], Loss: 0.000219, Val Loss: 0.000328
# Epoch [23/100], Loss: 0.000243, Val Loss: 0.000473
# Epoch [24/100], Loss: 0.000204, Val Loss: 0.000317
# Epoch [25/100], Loss: 0.000211, Val Loss: 0.000509
# Epoch [26/100], Loss: 0.000212, Val Loss: 0.000424
# Epoch [27/100], Loss: 0.000284, Val Loss: 0.000749
# Epoch [28/100], Loss: 0.000306, Val Loss: 0.000339
# Epoch [29/100], Loss: 0.000195, Val Loss: 0.000346
# Early stopping triggered after 29 epochs without improvement.

# %%
# 3. DDM Drift Detection and Stream Test
config = DDMConfig(
    warning_level=2.0,
    drift_level=3.0,
    min_num_instances=25  # Minimum number of instances before checking for concept drift
)
detector = DDM(config=config)
metric = PrequentialError(alpha=1.0)

def stream_test(X_test, y_test, metric, detector):
    """Simulate data stream over X_test and y_test and detect concept drift."""
    drift_flag = False
    cumulative_error = 0

    for i, (X, y) in enumerate(zip(X_test, y_test)):
        # Predict and compute error
        y_pred = model(X.unsqueeze(0).to(device)).cpu().detach().numpy()
        error = float(abs(y_pred.item() - y.item()))

        # Update the detector with the error
        detector.update(error)
        cumulative_error += error

        # Check for drift
        status = detector.status
        if status["drift"] and not drift_flag:
            drift_flag = True
            accuracy = 1 - (cumulative_error / (i + 1))
            print(f"Concept drift detected at step {i}. Accuracy: {accuracy:.4f}")
            
    # Final accuracy
    accuracy = 1 - (cumulative_error / len(X_test))
    if not drift_flag:
        print("No concept drift detected")
    print(f"Final accuracy: {accuracy:.4f}\n")




# Run stream test
stream_test(X_test, y_test, metric, detector)
# Out:
# No concept drift detected
# Final accuracy: 0.3499

# %% [markdown]
# # plotting

# %%
import matplotlib.pyplot as plt

# Updated stream_test function with tracking for plotting
def stream_test(X_test, y_test, detector):
    """Simulate data stream over X_test and y_test, detecting and plotting concept drift."""
    drift_flag = False
    cumulative_error = 0
    accuracies = []
    drift_points = []
    error_rates = []

    for i, (X, y) in enumerate(zip(X_test, y_test)):
        # Predict and compute error
        y_pred = model(X.unsqueeze(0).to(device)).cpu().detach().numpy()
        error = float(abs(y_pred.item() - y.item()))

        # Update the detector with the error
        detector.update(error)
        cumulative_error += error

        # Track accuracy and error rate
        accuracy = 1 - (cumulative_error / (i + 1))
        accuracies.append(accuracy)
        error_rates.append(error)

        # Check for drift
        status = detector.status
        if status["drift"] and not drift_flag:
            drift_flag = True
            drift_points.append(i)  # Record drift point
            print(f"Concept drift detected at step {i}. Accuracy: {accuracy:.4f}")

    # Final accuracy
    accuracy = 1 - (cumulative_error / len(X_test))
    if not drift_flag:
        print("No concept drift detected")
    print(f"Final accuracy: {accuracy:.4f}\n")

    return accuracies, drift_points, error_rates

# Run the stream test and get the data for plotting
accuracies, drift_points, error_rates = stream_test(X_test, y_test, detector)

# Plot the accuracy over time with drift points marked
plt.figure(figsize=(14, 6))

# Accuracy over time
plt.plot(accuracies, label='Accuracy over time')
plt.scatter(drift_points, [accuracies[i] for i in drift_points], color='red', marker='x', label='Drift detected')

# Formatting the plot
plt.title('Accuracy and Concept Drift Detection over Time')
plt.xlabel('Time Step')
plt.ylabel('Accuracy')
plt.legend()
plt.show()

# Plot error rate over time
plt.figure(figsize=(14, 6))
plt.plot(error_rates, label='Error Rate over time')
plt.title('Error Rate over Time')
plt.xlabel('Time Step')
plt.ylabel('Error Rate')
plt.legend()
plt.show()
# Out:
# No concept drift detected
# Final accuracy: 0.3499

# %% [markdown]
# ## plotting diffrently

# %%
config = DDMConfig(
    warning_level=0.04,
    drift_level=0.09,
    min_num_instances=2  # Minimum number of instances before checking for concept drift
)
detector = DDM(config=config)
metric = PrequentialError(alpha=1.0)

def stream_test(X_test, y_test, metric, detector):
    """Simulate data stream over X_test and y_test and detect concept drift."""
    drift_points = []
    cumulative_error = 0
    errors = []

    for i, (X, y) in enumerate(zip(X_test, y_test)):

        y_pred = model(X.unsqueeze(0).to(device)).cpu().detach().numpy()
        # Calculate error
        error = float(abs(y_pred.item() - y.item()))
        errors.append(error)

        # Update the detector with the error
        detector.update(error)
        cumulative_error += error

        # Check for drift
        status = detector.status
        if status["drift"]:
            drift_points.append(i)
            accuracy = 1 - (cumulative_error / (i + 1))
            print(f"Concept drift detected at step {i}. Accuracy: {accuracy:.4f}")

    # Final accuracy
    final_accuracy = 1 - (cumulative_error / len(X_test))
    print(f"Final accuracy: {final_accuracy:.4f}\n")
    
    return drift_points, errors

# 5. Run stream test
drift_points, errors = stream_test(X_test, y_test, metric, detector)

# 5. Run stream test
drift_points, errors = stream_test(X_test, y_test, metric, detector)

# 6. Visualize results
plt.figure(figsize=(12, 6))

# Plot error rates
plt.subplot(2, 1, 1)
plt.plot(errors, label='Error Rate', color='blue')
plt.axvline(x=500, color='red', linestyle='--', label='True Drift Point')
plt.title('Error Rates Over Time')
plt.xlabel('Sample Index')
plt.ylabel('Error Rate')
plt.legend()

# Plot detected drifts
plt.subplot(2, 1, 2)
plt.plot(range(len(errors)), [1 - (sum(errors[:i + 1]) / (i + 1)) for i in range(len(errors))], label='Accuracy', color='green')
plt.scatter(drift_points, [1 - (sum(errors[:i + 1]) / (i + 1)) for i in drift_points], color='red', label='Detected Drifts')
plt.axvline(x=500, color='red', linestyle='--', label='True Drift Point')
plt.title('Accuracy Over Time')
plt.xlabel('Sample Index')
plt.ylabel('Accuracy')
plt.legend()

plt.tight_layout()
plt.show()
# Out:
# Concept drift detected at step 1. Accuracy: 0.3314
# Concept drift detected at step 2. Accuracy: 0.3332
# Concept drift detected at step 3. Accuracy: 0.3334
# Concept drift detected at step 4. Accuracy: 0.3317
# Concept drift detected at step 5. Accuracy: 0.3337
# Concept drift detected at step 6. Accuracy: 0.3365
# Concept drift detected at step 7. Accuracy: 0.3400
# Concept drift detected at step 8. Accuracy: 0.3402
# Concept drift detected at step 9. Accuracy: 0.3395
# Concept drift detected at step 10. Accuracy: 0.3398
# Concept drift detected at step 11. Accuracy: 0.3418
# Concept drift detected at step 12. Accuracy: 0.3438
# Concept drift detected at step 13. Accuracy: 0.3456
# Concept drift detected at step 14. Accuracy: 0.3470
# Concept drift detected at step 15. Accuracy: 0.3480
# Concept drift detected at step 16. Accuracy: 0.3494
# Concept drift detected at step 17. Accuracy: 0.3503
# Concept drift detected at step 18. Accuracy: 0.3499
# Concept drift detected at step 19. Accuracy: 0.3494
# Concept drift detected at step 20. Accuracy: 0.3491
# Concept drift detected at step 21. Accuracy: 0.3501
# Concept drift detected at step 22. Accuracy: 0.3508
# Concept drift detected at step 23. Accuracy: 0.3512
# Concept drift detected at step 24. Accuracy: 0.3518
# Concept drift detected at step 25. Accuracy: 0.3525
# Concept drift detected at step 26. Accuracy: 0.3527
# Concept drift detected at step 27. Accuracy: 0.3528
# Concept drift detected at step 28. Accuracy: 0.3531
# Concept drift detected at step 29. Accuracy: 0.3535
# Concept drift detected at step 30. Accuracy: 0.3538
# Concept drift detected at step 31. Accuracy: 0.3539
# Concept drift detected at step 32. Accuracy: 0.3540
# Concept drift detected at step 33. Accuracy: 0.3541
# Concept drift detected at step 34. Accuracy: 0.3546
# Concept drift detected at step 35. Accuracy: 0.3552
# Concept drift detected at step 36. Accuracy: 0.3556
# Concept drift detected at step 37. Accuracy: 0.3557
# Concept drift detected at step 38. Accuracy: 0.3558
# Concept drift detected at step 39. Accuracy: 0.3560
# Concept drift detected at step 40. Accuracy: 0.3565
# Concept drift detected at step 41. Accuracy: 0.3573
# Concept drift detected at step 42. Accuracy: 0.3579
# Concept drift detected at step 43. Accuracy: 0.3583
# Concept drift detected at step 44. Accuracy: 0.3587
# Concept drift detected at step 45. Accuracy: 0.3593
# Concept drift detected at step 46. Accuracy: 0.3598
# Concept drift detected at step 47. Accuracy: 0.3605
# Concept drift detected at step 48. Accuracy: 0.3610
# Concept drift detected at step 49. Accuracy: 0.3614
# Concept drift detected at step 50. Accuracy: 0.3619
# Concept drift detected at step 51. Accuracy: 0.3624
# Concept drift detected at step 52. Accuracy: 0.3628
# Concept drift detected at step 53. Accuracy: 0.3631
# Concept drift detected at step 54. Accuracy: 0.3634
# Concept drift detected at step 55. Accuracy: 0.3636
# Concept drift detected at step 56. Accuracy: 0.3638
# Concept drift detected at step 57. Accuracy: 0.3640
# Concept drift detected at step 58. Accuracy: 0.3642
# Concept drift detected at step 59. Accuracy: 0.3644
# Concept drift detected at step 60. Accuracy: 0.3646
# Concept drift detected at step 61. Accuracy: 0.3648
# Concept drift detected at step 62. Accuracy: 0.3649
# Concept drift detected at step 63. Accuracy: 0.3649
# Concept drift detected at step 64. Accuracy: 0.3649
# Concept drift detected at step 65. Accuracy: 0.3650
# Concept drift detected at step 66. Accuracy: 0.3650
# Concept drift detected at step 67. Accuracy: 0.3652
# Concept drift detected at step 68. Accuracy: 0.3653
# Concept drift detected at step 69. Accuracy: 0.3654
# Concept drift detected at step 70. Accuracy: 0.3655
# Concept drift detected at step 71. Accuracy: 0.3658
# Concept drift detected at step 72. Accuracy: 0.3660
# Concept drift detected at step 73. Accuracy: 0.3662
# Concept drift detected at step 74. Accuracy: 0.3665
# Concept drift detected at step 75. Accuracy: 0.3667
# Concept drift detected at step 76. Accuracy: 0.3669
# Concept drift detected at step 77. Accuracy: 0.3672
# Concept drift detected at step 78. Accuracy: 0.3672
# Concept drift detected at step 79. Accuracy: 0.3672
# Concept drift detected at step 80. Accuracy: 0.3673
# Concept drift detected at step 81. Accuracy: 0.3673
# Concept drift detected at step 82. Accuracy: 0.3673
# Concept drift detected at step 83. Accuracy: 0.3672
# Concept drift detected at step 84. Accuracy: 0.3672
# Concept drift detected at step 85. Accuracy: 0.3672
# Concept drift detected at step 86. Accuracy: 0.3672
# Concept drift detected at step 87. Accuracy: 0.3673
# Concept drift detected at step 88. Accuracy: 0.3673
# Concept drift detected at step 89. Accuracy: 0.3672
# Concept drift detected at step 90. Accuracy: 0.3669
# Concept drift detected at step 91. Accuracy: 0.3665
# Concept drift detected at step 92. Accuracy: 0.3660
# Concept drift detected at step 93. Accuracy: 0.3655
# Concept drift detected at step 94. Accuracy: 0.3651
# Concept drift detected at step 95. Accuracy: 0.3648
# Concept drift detected at step 96. Accuracy: 0.3644
# Concept drift detected at step 97. Accuracy: 0.3641
# Concept drift detected at step 98. Accuracy: 0.3639
# Concept drift detected at step 99. Accuracy: 0.3636
# Concept drift detected at step 100. Accuracy: 0.3634
# Concept drift detected at step 101. Accuracy: 0.3632
# Concept drift detected at step 102. Accuracy: 0.3629
# Concept drift detected at step 103. Accuracy: 0.3626
# Concept drift detected at step 104. Accuracy: 0.3624
# Concept drift detected at step 105. Accuracy: 0.3621
# Concept drift detected at step 106. Accuracy: 0.3618
# Concept drift detected at step 107. Accuracy: 0.3617
# Concept drift detected at step 108. Accuracy: 0.3615
# Concept drift detected at step 109. Accuracy: 0.3613
# Concept drift detected at step 110. Accuracy: 0.3611
# Concept drift detected at step 111. Accuracy: 0.3609
# Concept drift detected at step 112. Accuracy: 0.3607
# Concept drift detected at step 113. Accuracy: 0.3605
# Concept drift detected at step 114. Accuracy: 0.3604
# Concept drift detected at step 115. Accuracy: 0.3602
# Concept drift detected at step 116. Accuracy: 0.3601
# Concept drift detected at step 117. Accuracy: 0.3599
# Concept drift detected at step 118. Accuracy: 0.3596
# Concept drift detected at step 119. Accuracy: 0.3594
# Concept drift detected at step 120. Accuracy: 0.3593
# Concept drift detected at step 121. Accuracy: 0.3590
# Concept drift detected at step 122. Accuracy: 0.3588
# Concept drift detected at step 123. Accuracy: 0.3587
# Concept drift detected at step 124. Accuracy: 0.3586
# Concept drift detected at step 125. Accuracy: 0.3585
# Concept drift detected at step 126. Accuracy: 0.3583
# Concept drift detected at step 127. Accuracy: 0.3582
# Concept drift detected at step 128. Accuracy: 0.3582
# Concept drift detected at step 129. Accuracy: 0.3581
# Concept drift detected at step 130. Accuracy: 0.3579
# Concept drift detected at step 131. Accuracy: 0.3577
# Concept drift detected at step 132. Accuracy: 0.3574
# Concept drift detected at step 133. Accuracy: 0.3572
# Concept drift detected at step 134. Accuracy: 0.3569
# Concept drift detected at step 135. Accuracy: 0.3566
# Concept drift detected at step 136. Accuracy: 0.3564
# Concept drift detected at step 137. Accuracy: 0.3563
# Concept drift detected at step 138. Accuracy: 0.3560
# Concept drift detected at step 139. Accuracy: 0.3558
# Concept drift detected at step 140. Accuracy: 0.3556
# Concept drift detected at step 141. Accuracy: 0.3554
# Concept drift detected at step 142. Accuracy: 0.3551
# Concept drift detected at step 143. Accuracy: 0.3547
# Concept drift detected at step 144. Accuracy: 0.3545
# Concept drift detected at step 145. Accuracy: 0.3542
# Concept drift detected at step 146. Accuracy: 0.3540
# Concept drift detected at step 147. Accuracy: 0.3538
# Concept drift detected at step 148. Accuracy: 0.3536
# Concept drift detected at step 149. Accuracy: 0.3536
# Concept drift detected at step 150. Accuracy: 0.3534
# Concept drift detected at step 151. Accuracy: 0.3533
# Concept drift detected at step 152. Accuracy: 0.3531
# Concept drift detected at step 153. Accuracy: 0.3530
# Concept drift detected at step 154. Accuracy: 0.3529
# Concept drift detected at step 155. Accuracy: 0.3527
# Concept drift detected at step 156. Accuracy: 0.3526
# Concept drift detected at step 157. Accuracy: 0.3525
# Concept drift detected at step 158. Accuracy: 0.3524
# Concept drift detected at step 159. Accuracy: 0.3524
# Concept drift detected at step 160. Accuracy: 0.3524
# Concept drift detected at step 161. Accuracy: 0.3524
# Concept drift detected at step 162. Accuracy: 0.3524
# Concept drift detected at step 163. Accuracy: 0.3524
# Concept drift detected at step 164. Accuracy: 0.3524
# Concept drift detected at step 165. Accuracy: 0.3524
# Concept drift detected at step 166. Accuracy: 0.3524
# Concept drift detected at step 167. Accuracy: 0.3524
# Concept drift detected at step 168. Accuracy: 0.3524
# Concept drift detected at step 169. Accuracy: 0.3524
# Concept drift detected at step 170. Accuracy: 0.3524
# Concept drift detected at step 171. Accuracy: 0.3523
# Concept drift detected at step 172. Accuracy: 0.3522
# Concept drift detected at step 173. Accuracy: 0.3522
# Concept drift detected at step 174. Accuracy: 0.3521
# Concept drift detected at step 175. Accuracy: 0.3520
# Concept drift detected at step 176. Accuracy: 0.3520
# Concept drift detected at step 177. Accuracy: 0.3519
# Concept drift detected at step 178. Accuracy: 0.3519
# Concept drift detected at step 179. Accuracy: 0.3519
# Concept drift detected at step 180. Accuracy: 0.3518
# Concept drift detected at step 181. Accuracy: 0.3517
# Concept drift detected at step 182. Accuracy: 0.3517
# Concept drift detected at step 183. Accuracy: 0.3517
# Concept drift detected at step 184. Accuracy: 0.3516
# Concept drift detected at step 185. Accuracy: 0.3516
# Concept drift detected at step 186. Accuracy: 0.3516
# Concept drift detected at step 187. Accuracy: 0.3516
# Concept drift detected at step 188. Accuracy: 0.3515
# Concept drift detected at step 189. Accuracy: 0.3515
# Concept drift detected at step 190. Accuracy: 0.3514
# Concept drift detected at step 191. Accuracy: 0.3514
# Concept drift detected at step 192. Accuracy: 0.3513
# Concept drift detected at step 193. Accuracy: 0.3512
# Concept drift detected at step 194. Accuracy: 0.3511
# Concept drift detected at step 195. Accuracy: 0.3510
# Concept drift detected at step 196. Accuracy: 0.3509
# Concept drift detected at step 197. Accuracy: 0.3508
# Concept drift detected at step 198. Accuracy: 0.3506
# Concept drift detected at step 199. Accuracy: 0.3504
# Concept drift detected at step 200. Accuracy: 0.3502
# Concept drift detected at step 201. Accuracy: 0.3501
# Concept drift detected at step 202. Accuracy: 0.3499
# Concept drift detected at step 203. Accuracy: 0.3497
# Concept drift detected at step 204. Accuracy: 0.3496
# Concept drift detected at step 205. Accuracy: 0.3495
# Concept drift detected at step 206. Accuracy: 0.3493
# Concept drift detected at step 207. Accuracy: 0.3491
# Concept drift detected at step 208. Accuracy: 0.3491
# Concept drift detected at step 209. Accuracy: 0.3491
# Concept drift detected at step 210. Accuracy: 0.3491
# Concept drift detected at step 211. Accuracy: 0.3491
# Concept drift detected at step 212. Accuracy: 0.3491
# Concept drift detected at step 213. Accuracy: 0.3490
# Concept drift detected at step 214. Accuracy: 0.3490
# Concept drift detected at step 215. Accuracy: 0.3489
# Concept drift detected at step 216. Accuracy: 0.3488
# Concept drift detected at step 217. Accuracy: 0.3487
# Concept drift detected at step 218. Accuracy: 0.3485
# Concept drift detected at step 219. Accuracy: 0.3484
# Concept drift detected at step 220. Accuracy: 0.3483
# Concept drift detected at step 221. Accuracy: 0.3482
# Concept drift detected at step 222. Accuracy: 0.3481
# Concept drift detected at step 223. Accuracy: 0.3480
# Concept drift detected at step 224. Accuracy: 0.3479
# Concept drift detected at step 225. Accuracy: 0.3478
# Concept drift detected at step 226. Accuracy: 0.3477
# Concept drift detected at step 227. Accuracy: 0.3477
# Concept drift detected at step 228. Accuracy: 0.3476
# Concept drift detected at step 229. Accuracy: 0.3475
# Concept drift detected at step 230. Accuracy: 0.3474
# Concept drift detected at step 231. Accuracy: 0.3473
# Concept drift detected at step 232. Accuracy: 0.3473
# Concept drift detected at step 233. Accuracy: 0.3472
# Concept drift detected at step 234. Accuracy: 0.3471
# Concept drift detected at step 235. Accuracy: 0.3470
# Concept drift detected at step 236. Accuracy: 0.3469
# Concept drift detected at step 237. Accuracy: 0.3468
# Concept drift detected at step 238. Accuracy: 0.3467
# Concept drift detected at step 239. Accuracy: 0.3466
# Concept drift detected at step 240. Accuracy: 0.3465
# Concept drift detected at step 241. Accuracy: 0.3465
# Concept drift detected at step 242. Accuracy: 0.3464
# Concept drift detected at step 243. Accuracy: 0.3463
# Concept drift detected at step 244. Accuracy: 0.3463
# Concept drift detected at step 245. Accuracy: 0.3462
# Concept drift detected at step 246. Accuracy: 0.3461
# Concept drift detected at step 247. Accuracy: 0.3460
# Concept drift detected at step 248. Accuracy: 0.3460
# Concept drift detected at step 249. Accuracy: 0.3459
# Concept drift detected at step 250. Accuracy: 0.3458
# Concept drift detected at step 251. Accuracy: 0.3457
# Concept drift detected at step 252. Accuracy: 0.3456
# Concept drift detected at step 253. Accuracy: 0.3455
# Concept drift detected at step 254. Accuracy: 0.3454
# Concept drift detected at step 255. Accuracy: 0.3453
# Concept drift detected at step 256. Accuracy: 0.3452
# Concept drift detected at step 257. Accuracy: 0.3451
# Concept drift detected at step 258. Accuracy: 0.3450
# Concept drift detected at step 259. Accuracy: 0.3449
# Concept drift detected at step 260. Accuracy: 0.3448
# Concept drift detected at step 261. Accuracy: 0.3447
# Concept drift detected at step 262. Accuracy: 0.3446
# Concept drift detected at step 263. Accuracy: 0.3444
# Concept drift detected at step 264. Accuracy: 0.3443
# Concept drift detected at step 265. Accuracy: 0.3442
# Concept drift detected at step 266. Accuracy: 0.3441
# Concept drift detected at step 267. Accuracy: 0.3440
# Concept drift detected at step 268. Accuracy: 0.3439
# Concept drift detected at step 269. Accuracy: 0.3438
# Concept drift detected at step 270. Accuracy: 0.3436
# Concept drift detected at step 271. Accuracy: 0.3435
# Concept drift detected at step 272. Accuracy: 0.3434
# Concept drift detected at step 273. Accuracy: 0.3433
# Concept drift detected at step 274. Accuracy: 0.3432
# Concept drift detected at step 275. Accuracy: 0.3430
# Concept drift detected at step 276. Accuracy: 0.3430
# Concept drift detected at step 277. Accuracy: 0.3429
# Concept drift detected at step 278. Accuracy: 0.3428
# Concept drift detected at step 279. Accuracy: 0.3427
# Concept drift detected at step 280. Accuracy: 0.3427
# Concept drift detected at step 281. Accuracy: 0.3426
# Concept drift detected at step 282. Accuracy: 0.3426
# Concept drift detected at step 283. Accuracy: 0.3426
# Concept drift detected at step 284. Accuracy: 0.3425
# Concept drift detected at step 285. Accuracy: 0.3425
# Concept drift detected at step 286. Accuracy: 0.3425
# Concept drift detected at step 287. Accuracy: 0.3424
# Concept drift detected at step 288. Accuracy: 0.3424
# Concept drift detected at step 289. Accuracy: 0.3424
# Concept drift detected at step 290. Accuracy: 0.3423
# Concept drift detected at step 291. Accuracy: 0.3423
# Concept drift detected at step 292. Accuracy: 0.3423
# Concept drift detected at step 293. Accuracy: 0.3423
# Concept drift detected at step 294. Accuracy: 0.3423
# Concept drift detected at step 295. Accuracy: 0.3422
# Concept drift detected at step 296. Accuracy: 0.3422
# Concept drift detected at step 297. Accuracy: 0.3422
# Concept drift detected at step 298. Accuracy: 0.3422
# Concept drift detected at step 299. Accuracy: 0.3422
# Concept drift detected at step 300. Accuracy: 0.3422
# Concept drift detected at step 301. Accuracy: 0.3422
# Concept drift detected at step 302. Accuracy: 0.3422
# Concept drift detected at step 303. Accuracy: 0.3422
# Concept drift detected at step 304. Accuracy: 0.3421
# Concept drift detected at step 305. Accuracy: 0.3421
# Concept drift detected at step 306. Accuracy: 0.3422
# Concept drift detected at step 307. Accuracy: 0.3422
# Concept drift detected at step 308. Accuracy: 0.3422
# Concept drift detected at step 309. Accuracy: 0.3422
# Concept drift detected at step 310. Accuracy: 0.3422
# Concept drift detected at step 311. Accuracy: 0.3422
# Concept drift detected at step 312. Accuracy: 0.3423
# Concept drift detected at step 313. Accuracy: 0.3423
# Concept drift detected at step 314. Accuracy: 0.3423
# Concept drift detected at step 315. Accuracy: 0.3423
# Concept drift detected at step 316. Accuracy: 0.3423
# Concept drift detected at step 317. Accuracy: 0.3423
# Concept drift detected at step 318. Accuracy: 0.3424
# Concept drift detected at step 319. Accuracy: 0.3424
# Concept drift detected at step 320. Accuracy: 0.3424
# Concept drift detected at step 321. Accuracy: 0.3424
# Concept drift detected at step 322. Accuracy: 0.3424
# Concept drift detected at step 323. Accuracy: 0.3425
# Concept drift detected at step 324. Accuracy: 0.3425
# Concept drift detected at step 325. Accuracy: 0.3426
# Concept drift detected at step 326. Accuracy: 0.3427
# Concept drift detected at step 327. Accuracy: 0.3428
# Concept drift detected at step 328. Accuracy: 0.3430
# Concept drift detected at step 329. Accuracy: 0.3431
# Concept drift detected at step 330. Accuracy: 0.3433
# Concept drift detected at step 331. Accuracy: 0.3435
# Concept drift detected at step 332. Accuracy: 0.3436
# Concept drift detected at step 333. Accuracy: 0.3438
# Concept drift detected at step 334. Accuracy: 0.3440
# Concept drift detected at step 335. Accuracy: 0.3441
# Concept drift detected at step 336. Accuracy: 0.3443
# Concept drift detected at step 337. Accuracy: 0.3444
# Concept drift detected at step 338. Accuracy: 0.3445
# Concept drift detected at step 339. Accuracy: 0.3446
# Concept drift detected at step 340. Accuracy: 0.3448
# Concept drift detected at step 341. Accuracy: 0.3449
# Concept drift detected at step 342. Accuracy: 0.3450
# Concept drift detected at step 343. Accuracy: 0.3451
# Concept drift detected at step 344. Accuracy: 0.3452
# Concept drift detected at step 345. Accuracy: 0.3453
# Concept drift detected at step 346. Accuracy: 0.3454
# Concept drift detected at step 347. Accuracy: 0.3455
# Concept drift detected at step 348. Accuracy: 0.3456
# Concept drift detected at step 349. Accuracy: 0.3457
# Concept drift detected at step 350. Accuracy: 0.3458
# Concept drift detected at step 351. Accuracy: 0.3459
# Concept drift detected at step 352. Accuracy: 0.3460
# Concept drift detected at step 353. Accuracy: 0.3460
# Concept drift detected at step 354. Accuracy: 0.3461
# Concept drift detected at step 355. Accuracy: 0.3462
# Concept drift detected at step 356. Accuracy: 0.3463
# Concept drift detected at step 357. Accuracy: 0.3464
# Concept drift detected at step 358. Accuracy: 0.3465
# Concept drift detected at step 359. Accuracy: 0.3465
# Concept drift detected at step 360. Accuracy: 0.3466
# Concept drift detected at step 361. Accuracy: 0.3467
# Concept drift detected at step 362. Accuracy: 0.3468
# Concept drift detected at step 363. Accuracy: 0.3469
# Concept drift detected at step 364. Accuracy: 0.3470
# Concept drift detected at step 365. Accuracy: 0.3471
# Concept drift detected at step 366. Accuracy: 0.3472
# Concept drift detected at step 367. Accuracy: 0.3472
# Concept drift detected at step 368. Accuracy: 0.3473
# Concept drift detected at step 369. Accuracy: 0.3474
# Concept drift detected at step 370. Accuracy: 0.3475
# Concept drift detected at step 371. Accuracy: 0.3476
# Concept drift detected at step 372. Accuracy: 0.3477
# Concept drift detected at step 373. Accuracy: 0.3478
# Concept drift detected at step 374. Accuracy: 0.3479
# Concept drift detected at step 375. Accuracy: 0.3480
# Concept drift detected at step 376. Accuracy: 0.3481
# Concept drift detected at step 377. Accuracy: 0.3482
# Concept drift detected at step 378. Accuracy: 0.3484
# Concept drift detected at step 379. Accuracy: 0.3485
# Concept drift detected at step 380. Accuracy: 0.3486
# Concept drift detected at step 381. Accuracy: 0.3488
# Concept drift detected at step 382. Accuracy: 0.3489
# Concept drift detected at step 383. Accuracy: 0.3490
# Concept drift detected at step 384. Accuracy: 0.3491
# Concept drift detected at step 385. Accuracy: 0.3492
# Concept drift detected at step 386. Accuracy: 0.3493
# Concept drift detected at step 387. Accuracy: 0.3494
# Concept drift detected at step 388. Accuracy: 0.3495
# Concept drift detected at step 389. Accuracy: 0.3496
# Concept drift detected at step 390. Accuracy: 0.3497
# Concept drift detected at step 391. Accuracy: 0.3498
# Concept drift detected at step 392. Accuracy: 0.3498
# Concept drift detected at step 393. Accuracy: 0.3499
# Final accuracy: 0.3499
#
# Concept drift detected at step 0. Accuracy: 0.3298
# Concept drift detected at step 1. Accuracy: 0.3314
# Concept drift detected at step 2. Accuracy: 0.3332
# Concept drift detected at step 3. Accuracy: 0.3334
# Concept drift detected at step 4. Accuracy: 0.3317
# Concept drift detected at step 5. Accuracy: 0.3337
# Concept drift detected at step 6. Accuracy: 0.3365
# Concept drift detected at step 7. Accuracy: 0.3400
# Concept drift detected at step 8. Accuracy: 0.3402
# Concept drift detected at step 9. Accuracy: 0.3395
# Concept drift detected at step 10. Accuracy: 0.3398
# Concept drift detected at step 11. Accuracy: 0.3418
# Concept drift detected at step 12. Accuracy: 0.3438
# Concept drift detected at step 13. Accuracy: 0.3456
# Concept drift detected at step 14. Accuracy: 0.3470
# Concept drift detected at step 15. Accuracy: 0.3480
# Concept drift detected at step 16. Accuracy: 0.3494
# Concept drift detected at step 17. Accuracy: 0.3503
# Concept drift detected at step 18. Accuracy: 0.3499
# Concept drift detected at step 19. Accuracy: 0.3494
# Concept drift detected at step 20. Accuracy: 0.3491
# Concept drift detected at step 21. Accuracy: 0.3501
# Concept drift detected at step 22. Accuracy: 0.3508
# Concept drift detected at step 23. Accuracy: 0.3512
# Concept drift detected at step 24. Accuracy: 0.3518
# Concept drift detected at step 25. Accuracy: 0.3525
# Concept drift detected at step 26. Accuracy: 0.3527
# Concept drift detected at step 27. Accuracy: 0.3528
# Concept drift detected at step 28. Accuracy: 0.3531
# Concept drift detected at step 29. Accuracy: 0.3535
# Concept drift detected at step 30. Accuracy: 0.3538
# Concept drift detected at step 31. Accuracy: 0.3539
# Concept drift detected at step 32. Accuracy: 0.3540
# Concept drift detected at step 33. Accuracy: 0.3541
# Concept drift detected at step 34. Accuracy: 0.3546
# Concept drift detected at step 35. Accuracy: 0.3552
# Concept drift detected at step 36. Accuracy: 0.3556
# Concept drift detected at step 37. Accuracy: 0.3557
# Concept drift detected at step 38. Accuracy: 0.3558
# Concept drift detected at step 39. Accuracy: 0.3560
# Concept drift detected at step 40. Accuracy: 0.3565
# Concept drift detected at step 41. Accuracy: 0.3573
# Concept drift detected at step 42. Accuracy: 0.3579
# Concept drift detected at step 43. Accuracy: 0.3583
# Concept drift detected at step 44. Accuracy: 0.3587
# Concept drift detected at step 45. Accuracy: 0.3593
# Concept drift detected at step 46. Accuracy: 0.3598
# Concept drift detected at step 47. Accuracy: 0.3605
# Concept drift detected at step 48. Accuracy: 0.3610
# Concept drift detected at step 49. Accuracy: 0.3614
# Concept drift detected at step 50. Accuracy: 0.3619
# Concept drift detected at step 51. Accuracy: 0.3624
# Concept drift detected at step 52. Accuracy: 0.3628
# Concept drift detected at step 53. Accuracy: 0.3631
# Concept drift detected at step 54. Accuracy: 0.3634
# Concept drift detected at step 55. Accuracy: 0.3636
# Concept drift detected at step 56. Accuracy: 0.3638
# Concept drift detected at step 57. Accuracy: 0.3640
# Concept drift detected at step 58. Accuracy: 0.3642
# Concept drift detected at step 59. Accuracy: 0.3644
# Concept drift detected at step 60. Accuracy: 0.3646
# Concept drift detected at step 61. Accuracy: 0.3648
# Concept drift detected at step 62. Accuracy: 0.3649
# Concept drift detected at step 63. Accuracy: 0.3649
# Concept drift detected at step 64. Accuracy: 0.3649
# Concept drift detected at step 65. Accuracy: 0.3650
# Concept drift detected at step 66. Accuracy: 0.3650
# Concept drift detected at step 67. Accuracy: 0.3652
# Concept drift detected at step 68. Accuracy: 0.3653
# Concept drift detected at step 69. Accuracy: 0.3654
# Concept drift detected at step 70. Accuracy: 0.3655
# Concept drift detected at step 71. Accuracy: 0.3658
# Concept drift detected at step 72. Accuracy: 0.3660
# Concept drift detected at step 73. Accuracy: 0.3662
# Concept drift detected at step 74. Accuracy: 0.3665
# Concept drift detected at step 75. Accuracy: 0.3667
# Concept drift detected at step 76. Accuracy: 0.3669
# Concept drift detected at step 77. Accuracy: 0.3672
# Concept drift detected at step 78. Accuracy: 0.3672
# Concept drift detected at step 79. Accuracy: 0.3672
# Concept drift detected at step 80. Accuracy: 0.3673
# Concept drift detected at step 81. Accuracy: 0.3673
# Concept drift detected at step 82. Accuracy: 0.3673
# Concept drift detected at step 83. Accuracy: 0.3672
# Concept drift detected at step 84. Accuracy: 0.3672
# Concept drift detected at step 85. Accuracy: 0.3672
# Concept drift detected at step 86. Accuracy: 0.3672
# Concept drift detected at step 87. Accuracy: 0.3673
# Concept drift detected at step 88. Accuracy: 0.3673
# Concept drift detected at step 89. Accuracy: 0.3672
# Concept drift detected at step 90. Accuracy: 0.3669
# Concept drift detected at step 91. Accuracy: 0.3665
# Concept drift detected at step 92. Accuracy: 0.3660
# Concept drift detected at step 93. Accuracy: 0.3655
# Concept drift detected at step 94. Accuracy: 0.3651
# Concept drift detected at step 95. Accuracy: 0.3648
# Concept drift detected at step 96. Accuracy: 0.3644
# Concept drift detected at step 97. Accuracy: 0.3641
# Concept drift detected at step 98. Accuracy: 0.3639
# Concept drift detected at step 99. Accuracy: 0.3636
# Concept drift detected at step 100. Accuracy: 0.3634
# Concept drift detected at step 101. Accuracy: 0.3632
# Concept drift detected at step 102. Accuracy: 0.3629
# Concept drift detected at step 103. Accuracy: 0.3626
# Concept drift detected at step 104. Accuracy: 0.3624
# Concept drift detected at step 105. Accuracy: 0.3621
# Concept drift detected at step 106. Accuracy: 0.3618
# Concept drift detected at step 107. Accuracy: 0.3617
# Concept drift detected at step 108. Accuracy: 0.3615
# Concept drift detected at step 109. Accuracy: 0.3613
# Concept drift detected at step 110. Accuracy: 0.3611
# Concept drift detected at step 111. Accuracy: 0.3609
# Concept drift detected at step 112. Accuracy: 0.3607
# Concept drift detected at step 113. Accuracy: 0.3605
# Concept drift detected at step 114. Accuracy: 0.3604
# Concept drift detected at step 115. Accuracy: 0.3602
# Concept drift detected at step 116. Accuracy: 0.3601
# Concept drift detected at step 117. Accuracy: 0.3599
# Concept drift detected at step 118. Accuracy: 0.3596
# Concept drift detected at step 119. Accuracy: 0.3594
# Concept drift detected at step 120. Accuracy: 0.3593
# Concept drift detected at step 121. Accuracy: 0.3590
# Concept drift detected at step 122. Accuracy: 0.3588
# Concept drift detected at step 123. Accuracy: 0.3587
# Concept drift detected at step 124. Accuracy: 0.3586
# Concept drift detected at step 125. Accuracy: 0.3585
# Concept drift detected at step 126. Accuracy: 0.3583
# Concept drift detected at step 127. Accuracy: 0.3582
# Concept drift detected at step 128. Accuracy: 0.3582
# Concept drift detected at step 129. Accuracy: 0.3581
# Concept drift detected at step 130. Accuracy: 0.3579
# Concept drift detected at step 131. Accuracy: 0.3577
# Concept drift detected at step 132. Accuracy: 0.3574
# Concept drift detected at step 133. Accuracy: 0.3572
# Concept drift detected at step 134. Accuracy: 0.3569
# Concept drift detected at step 135. Accuracy: 0.3566
# Concept drift detected at step 136. Accuracy: 0.3564
# Concept drift detected at step 137. Accuracy: 0.3563
# Concept drift detected at step 138. Accuracy: 0.3560
# Concept drift detected at step 139. Accuracy: 0.3558
# Concept drift detected at step 140. Accuracy: 0.3556
# Concept drift detected at step 141. Accuracy: 0.3554
# Concept drift detected at step 142. Accuracy: 0.3551
# Concept drift detected at step 143. Accuracy: 0.3547
# Concept drift detected at step 144. Accuracy: 0.3545
# Concept drift detected at step 145. Accuracy: 0.3542
# Concept drift detected at step 146. Accuracy: 0.3540
# Concept drift detected at step 147. Accuracy: 0.3538
# Concept drift detected at step 148. Accuracy: 0.3536
# Concept drift detected at step 149. Accuracy: 0.3536
# Concept drift detected at step 150. Accuracy: 0.3534
# Concept drift detected at step 151. Accuracy: 0.3533
# Concept drift detected at step 152. Accuracy: 0.3531
# Concept drift detected at step 153. Accuracy: 0.3530
# Concept drift detected at step 154. Accuracy: 0.3529
# Concept drift detected at step 155. Accuracy: 0.3527
# Concept drift detected at step 156. Accuracy: 0.3526
# Concept drift detected at step 157. Accuracy: 0.3525
# Concept drift detected at step 158. Accuracy: 0.3524
# Concept drift detected at step 159. Accuracy: 0.3524
# Concept drift detected at step 160. Accuracy: 0.3524
# Concept drift detected at step 161. Accuracy: 0.3524
# Concept drift detected at step 162. Accuracy: 0.3524
# Concept drift detected at step 163. Accuracy: 0.3524
# Concept drift detected at step 164. Accuracy: 0.3524
# Concept drift detected at step 165. Accuracy: 0.3524
# Concept drift detected at step 166. Accuracy: 0.3524
# Concept drift detected at step 167. Accuracy: 0.3524
# Concept drift detected at step 168. Accuracy: 0.3524
# Concept drift detected at step 169. Accuracy: 0.3524
# Concept drift detected at step 170. Accuracy: 0.3524
# Concept drift detected at step 171. Accuracy: 0.3523
# Concept drift detected at step 172. Accuracy: 0.3522
# Concept drift detected at step 173. Accuracy: 0.3522
# Concept drift detected at step 174. Accuracy: 0.3521
# Concept drift detected at step 175. Accuracy: 0.3520
# Concept drift detected at step 176. Accuracy: 0.3520
# Concept drift detected at step 177. Accuracy: 0.3519
# Concept drift detected at step 178. Accuracy: 0.3519
# Concept drift detected at step 179. Accuracy: 0.3519
# Concept drift detected at step 180. Accuracy: 0.3518
# Concept drift detected at step 181. Accuracy: 0.3517
# Concept drift detected at step 182. Accuracy: 0.3517
# Concept drift detected at step 183. Accuracy: 0.3517
# Concept drift detected at step 184. Accuracy: 0.3516
# Concept drift detected at step 185. Accuracy: 0.3516
# Concept drift detected at step 186. Accuracy: 0.3516
# Concept drift detected at step 187. Accuracy: 0.3516
# Concept drift detected at step 188. Accuracy: 0.3515
# Concept drift detected at step 189. Accuracy: 0.3515
# Concept drift detected at step 190. Accuracy: 0.3514
# Concept drift detected at step 191. Accuracy: 0.3514
# Concept drift detected at step 192. Accuracy: 0.3513
# Concept drift detected at step 193. Accuracy: 0.3512
# Concept drift detected at step 194. Accuracy: 0.3511
# Concept drift detected at step 195. Accuracy: 0.3510
# Concept drift detected at step 196. Accuracy: 0.3509
# Concept drift detected at step 197. Accuracy: 0.3508
# Concept drift detected at step 198. Accuracy: 0.3506
# Concept drift detected at step 199. Accuracy: 0.3504
# Concept drift detected at step 200. Accuracy: 0.3502
# Concept drift detected at step 201. Accuracy: 0.3501
# Concept drift detected at step 202. Accuracy: 0.3499
# Concept drift detected at step 203. Accuracy: 0.3497
# Concept drift detected at step 204. Accuracy: 0.3496
# Concept drift detected at step 205. Accuracy: 0.3495
# Concept drift detected at step 206. Accuracy: 0.3493
# Concept drift detected at step 207. Accuracy: 0.3491
# Concept drift detected at step 208. Accuracy: 0.3491
# Concept drift detected at step 209. Accuracy: 0.3491
# Concept drift detected at step 210. Accuracy: 0.3491
# Concept drift detected at step 211. Accuracy: 0.3491
# Concept drift detected at step 212. Accuracy: 0.3491
# Concept drift detected at step 213. Accuracy: 0.3490
# Concept drift detected at step 214. Accuracy: 0.3490
# Concept drift detected at step 215. Accuracy: 0.3489
# Concept drift detected at step 216. Accuracy: 0.3488
# Concept drift detected at step 217. Accuracy: 0.3487
# Concept drift detected at step 218. Accuracy: 0.3485
# Concept drift detected at step 219. Accuracy: 0.3484
# Concept drift detected at step 220. Accuracy: 0.3483
# Concept drift detected at step 221. Accuracy: 0.3482
# Concept drift detected at step 222. Accuracy: 0.3481
# Concept drift detected at step 223. Accuracy: 0.3480
# Concept drift detected at step 224. Accuracy: 0.3479
# Concept drift detected at step 225. Accuracy: 0.3478
# Concept drift detected at step 226. Accuracy: 0.3477
# Concept drift detected at step 227. Accuracy: 0.3477
# Concept drift detected at step 228. Accuracy: 0.3476
# Concept drift detected at step 229. Accuracy: 0.3475
# Concept drift detected at step 230. Accuracy: 0.3474
# Concept drift detected at step 231. Accuracy: 0.3473
# Concept drift detected at step 232. Accuracy: 0.3473
# Concept drift detected at step 233. Accuracy: 0.3472
# Concept drift detected at step 234. Accuracy: 0.3471
# Concept drift detected at step 235. Accuracy: 0.3470
# Concept drift detected at step 236. Accuracy: 0.3469
# Concept drift detected at step 237. Accuracy: 0.3468
# Concept drift detected at step 238. Accuracy: 0.3467
# Concept drift detected at step 239. Accuracy: 0.3466
# Concept drift detected at step 240. Accuracy: 0.3465
# Concept drift detected at step 241. Accuracy: 0.3465
# Concept drift detected at step 242. Accuracy: 0.3464
# Concept drift detected at step 243. Accuracy: 0.3463
# Concept drift detected at step 244. Accuracy: 0.3463
# Concept drift detected at step 245. Accuracy: 0.3462
# Concept drift detected at step 246. Accuracy: 0.3461
# Concept drift detected at step 247. Accuracy: 0.3460
# Concept drift detected at step 248. Accuracy: 0.3460
# Concept drift detected at step 249. Accuracy: 0.3459
# Concept drift detected at step 250. Accuracy: 0.3458
# Concept drift detected at step 251. Accuracy: 0.3457
# Concept drift detected at step 252. Accuracy: 0.3456
# Concept drift detected at step 253. Accuracy: 0.3455
# Concept drift detected at step 254. Accuracy: 0.3454
# Concept drift detected at step 255. Accuracy: 0.3453
# Concept drift detected at step 256. Accuracy: 0.3452
# Concept drift detected at step 257. Accuracy: 0.3451
# Concept drift detected at step 258. Accuracy: 0.3450
# Concept drift detected at step 259. Accuracy: 0.3449
# Concept drift detected at step 260. Accuracy: 0.3448
# Concept drift detected at step 261. Accuracy: 0.3447
# Concept drift detected at step 262. Accuracy: 0.3446
# Concept drift detected at step 263. Accuracy: 0.3444
# Concept drift detected at step 264. Accuracy: 0.3443
# Concept drift detected at step 265. Accuracy: 0.3442
# Concept drift detected at step 266. Accuracy: 0.3441
# Concept drift detected at step 267. Accuracy: 0.3440
# Concept drift detected at step 268. Accuracy: 0.3439
# Concept drift detected at step 269. Accuracy: 0.3438
# Concept drift detected at step 270. Accuracy: 0.3436
# Concept drift detected at step 271. Accuracy: 0.3435
# Concept drift detected at step 272. Accuracy: 0.3434
# Concept drift detected at step 273. Accuracy: 0.3433
# Concept drift detected at step 274. Accuracy: 0.3432
# Concept drift detected at step 275. Accuracy: 0.3430
# Concept drift detected at step 276. Accuracy: 0.3430
# Concept drift detected at step 277. Accuracy: 0.3429
# Concept drift detected at step 278. Accuracy: 0.3428
# Concept drift detected at step 279. Accuracy: 0.3427
# Concept drift detected at step 280. Accuracy: 0.3427
# Concept drift detected at step 281. Accuracy: 0.3426
# Concept drift detected at step 282. Accuracy: 0.3426
# Concept drift detected at step 283. Accuracy: 0.3426
# Concept drift detected at step 284. Accuracy: 0.3425
# Concept drift detected at step 285. Accuracy: 0.3425
# Concept drift detected at step 286. Accuracy: 0.3425
# Concept drift detected at step 287. Accuracy: 0.3424
# Concept drift detected at step 288. Accuracy: 0.3424
# Concept drift detected at step 289. Accuracy: 0.3424
# Concept drift detected at step 290. Accuracy: 0.3423
# Concept drift detected at step 291. Accuracy: 0.3423
# Concept drift detected at step 292. Accuracy: 0.3423
# Concept drift detected at step 293. Accuracy: 0.3423
# Concept drift detected at step 294. Accuracy: 0.3423
# Concept drift detected at step 295. Accuracy: 0.3422
# Concept drift detected at step 296. Accuracy: 0.3422
# Concept drift detected at step 297. Accuracy: 0.3422
# Concept drift detected at step 298. Accuracy: 0.3422
# Concept drift detected at step 299. Accuracy: 0.3422
# Concept drift detected at step 300. Accuracy: 0.3422
# Concept drift detected at step 301. Accuracy: 0.3422
# Concept drift detected at step 302. Accuracy: 0.3422
# Concept drift detected at step 303. Accuracy: 0.3422
# Concept drift detected at step 304. Accuracy: 0.3421
# Concept drift detected at step 305. Accuracy: 0.3421
# Concept drift detected at step 306. Accuracy: 0.3422
# Concept drift detected at step 307. Accuracy: 0.3422
# Concept drift detected at step 308. Accuracy: 0.3422
# Concept drift detected at step 309. Accuracy: 0.3422
# Concept drift detected at step 310. Accuracy: 0.3422
# Concept drift detected at step 311. Accuracy: 0.3422
# Concept drift detected at step 312. Accuracy: 0.3423
# Concept drift detected at step 313. Accuracy: 0.3423
# Concept drift detected at step 314. Accuracy: 0.3423
# Concept drift detected at step 315. Accuracy: 0.3423
# Concept drift detected at step 316. Accuracy: 0.3423
# Concept drift detected at step 317. Accuracy: 0.3423
# Concept drift detected at step 318. Accuracy: 0.3424
# Concept drift detected at step 319. Accuracy: 0.3424
# Concept drift detected at step 320. Accuracy: 0.3424
# Concept drift detected at step 321. Accuracy: 0.3424
# Concept drift detected at step 322. Accuracy: 0.3424
# Concept drift detected at step 323. Accuracy: 0.3425
# Concept drift detected at step 324. Accuracy: 0.3425
# Concept drift detected at step 325. Accuracy: 0.3426
# Concept drift detected at step 326. Accuracy: 0.3427
# Concept drift detected at step 327. Accuracy: 0.3428
# Concept drift detected at step 328. Accuracy: 0.3430
# Concept drift detected at step 329. Accuracy: 0.3431
# Concept drift detected at step 330. Accuracy: 0.3433
# Concept drift detected at step 331. Accuracy: 0.3435
# Concept drift detected at step 332. Accuracy: 0.3436
# Concept drift detected at step 333. Accuracy: 0.3438
# Concept drift detected at step 334. Accuracy: 0.3440
# Concept drift detected at step 335. Accuracy: 0.3441
# Concept drift detected at step 336. Accuracy: 0.3443
# Concept drift detected at step 337. Accuracy: 0.3444
# Concept drift detected at step 338. Accuracy: 0.3445
# Concept drift detected at step 339. Accuracy: 0.3446
# Concept drift detected at step 340. Accuracy: 0.3448
# Concept drift detected at step 341. Accuracy: 0.3449
# Concept drift detected at step 342. Accuracy: 0.3450
# Concept drift detected at step 343. Accuracy: 0.3451
# Concept drift detected at step 344. Accuracy: 0.3452
# Concept drift detected at step 345. Accuracy: 0.3453
# Concept drift detected at step 346. Accuracy: 0.3454
# Concept drift detected at step 347. Accuracy: 0.3455
# Concept drift detected at step 348. Accuracy: 0.3456
# Concept drift detected at step 349. Accuracy: 0.3457
# Concept drift detected at step 350. Accuracy: 0.3458
# Concept drift detected at step 351. Accuracy: 0.3459
# Concept drift detected at step 352. Accuracy: 0.3460
# Concept drift detected at step 353. Accuracy: 0.3460
# Concept drift detected at step 354. Accuracy: 0.3461
# Concept drift detected at step 355. Accuracy: 0.3462
# Concept drift detected at step 356. Accuracy: 0.3463
# Concept drift detected at step 357. Accuracy: 0.3464
# Concept drift detected at step 358. Accuracy: 0.3465
# Concept drift detected at step 359. Accuracy: 0.3465
# Concept drift detected at step 360. Accuracy: 0.3466
# Concept drift detected at step 361. Accuracy: 0.3467
# Concept drift detected at step 362. Accuracy: 0.3468
# Concept drift detected at step 363. Accuracy: 0.3469
# Concept drift detected at step 364. Accuracy: 0.3470
# Concept drift detected at step 365. Accuracy: 0.3471
# Concept drift detected at step 366. Accuracy: 0.3472
# Concept drift detected at step 367. Accuracy: 0.3472
# Concept drift detected at step 368. Accuracy: 0.3473
# Concept drift detected at step 369. Accuracy: 0.3474
# Concept drift detected at step 370. Accuracy: 0.3475
# Concept drift detected at step 371. Accuracy: 0.3476
# Concept drift detected at step 372. Accuracy: 0.3477
# Concept drift detected at step 373. Accuracy: 0.3478
# Concept drift detected at step 374. Accuracy: 0.3479
# Concept drift detected at step 375. Accuracy: 0.3480
# Concept drift detected at step 376. Accuracy: 0.3481
# Concept drift detected at step 377. Accuracy: 0.3482
# Concept drift detected at step 378. Accuracy: 0.3484
# Concept drift detected at step 379. Accuracy: 0.3485
# Concept drift detected at step 380. Accuracy: 0.3486
# Concept drift detected at step 381. Accuracy: 0.3488
# Concept drift detected at step 382. Accuracy: 0.3489
# Concept drift detected at step 383. Accuracy: 0.3490
# Concept drift detected at step 384. Accuracy: 0.3491
# Concept drift detected at step 385. Accuracy: 0.3492
# Concept drift detected at step 386. Accuracy: 0.3493
# Concept drift detected at step 387. Accuracy: 0.3494
# Concept drift detected at step 388. Accuracy: 0.3495
# Concept drift detected at step 389. Accuracy: 0.3496
# Concept drift detected at step 390. Accuracy: 0.3497
# Concept drift detected at step 391. Accuracy: 0.3498
# Concept drift detected at step 392. Accuracy: 0.3498
# Concept drift detected at step 393. Accuracy: 0.3499
# Final accuracy: 0.3499

# %% [markdown]
# ## Detector efficeny measurement

# %%
import numpy as np
import matplotlib.pyplot as plt
import torch
import torch.nn as nn
import torch.optim as optim
from frouros.detectors.concept_drift import DDM, DDMConfig
from frouros.metrics import PrequentialError


# 1. Create synthetic data with an abrupt drift
def create_synthetic_data(num_samples=1000):
    """Create synthetic data with an abrupt drift."""
    X = np.random.randn(num_samples, 1)  # Initial distribution
    y = (X > 0).astype(np.float32)  # Binary classification based on X
    
    # Introduce a drift at sample 500
    X[500:] += 2  # Shift the distribution
    y[500:] = (X[500:] > 0).astype(np.float32)  # Update labels based on the new distribution
    
    return torch.tensor(X, dtype=torch.float32), torch.tensor(y, dtype=torch.float32)

X_synthetic, y_synthetic = create_synthetic_data()

# 2. Create a simple model (adjust as needed for your task)
class SimpleModel(nn.Module):
    def __init__(self):
        super(SimpleModel, self).__init__()
        self.fc = nn.Linear(1, 1)

    def forward(self, x):
        return torch.sigmoid(self.fc(x))

model = SimpleModel()
optimizer = optim.Adam(model.parameters(), lr=0.01)
criterion = nn.BCELoss()

# 3. Initialize the DDM detector and metric
config = DDMConfig(
    warning_level=2.0,
    drift_level=3.0,
    min_num_instances=25  # Minimum number of instances before checking for concept drift
)
detector = DDM(config=config)
metric = PrequentialError(alpha=1.0)

# 4. Stream test function
def stream_test(X_test, y_test, metric, detector):
    """Simulate data stream over X_test and y_test and detect concept drift."""
    drift_points = []
    cumulative_error = 0
    errors = []

    for i, (X, y) in enumerate(zip(X_test, y_test)):
        # Predict and compute error
        y_pred = model(X.unsqueeze(0)).cpu().detach().numpy()
        error = float(abs(y_pred.item() - y.item()))
        errors.append(error)

        # Update the detector with the error
        detector.update(error)
        cumulative_error += error

        # Check for drift
        status = detector.status
        if status["drift"]:
            drift_points.append(i)
            accuracy = 1 - (cumulative_error / (i + 1))
            print(f"Concept drift detected at step {i}. Accuracy: {accuracy:.4f}")

    # Final accuracy
    final_accuracy = 1 - (cumulative_error / len(X_test))
    print(f"Final accuracy: {final_accuracy:.4f}\n")
    
    return drift_points, errors

# 5. Run stream test
drift_points, errors = stream_test(X_synthetic, y_synthetic, metric, detector)

# 6. Visualize results
plt.figure(figsize=(12, 6))

# Plot error rates
plt.subplot(2, 1, 1)
plt.plot(errors, label='Error Rate', color='blue')
plt.axvline(x=500, color='red', linestyle='--', label='True Drift Point')
plt.title('Error Rates Over Time')
plt.xlabel('Sample Index')
plt.ylabel('Error Rate')
plt.legend()

# Plot detected drifts
plt.subplot(2, 1, 2)
plt.plot(range(len(errors)), [1 - (sum(errors[:i + 1]) / (i + 1)) for i in range(len(errors))], label='Accuracy', color='green')
plt.scatter(drift_points, [1 - (sum(errors[:i + 1]) / (i + 1)) for i in drift_points], color='red', label='Detected Drifts')
plt.axvline(x=500, color='red', linestyle='--', label='True Drift Point')
plt.title('Accuracy Over Time')
plt.xlabel('Sample Index')
plt.ylabel('Accuracy')
plt.legend()

plt.tight_layout()
plt.show()
# Out:
# Final accuracy: 0.7508
